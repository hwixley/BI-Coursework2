# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from Bio import Entrez
from tqdm import tqdm

# %%
data = pd.read_csv (r'data/SFARI-Genes.csv')
cols = data.columns
N, D = data.shape
print(cols)
# Out:
# Index(['status', 'gene-symbol', 'gene-name', 'ensembl-id', 'chromosome',
#        'genetic-category', 'gene-score', 'syndromic', 'number-of-reports'],
#       dtype='object')

# %%
gene_symbols = data["gene-symbol"].values

# %%
data
# Out:
#       status gene-symbol                                          gene-name  \
# 0          9        ABAT                   4-aminobutyrate aminotransferase
# 1          9      ABCA10  ATP-binding cassette, sub-family A (ABC1), mem...
# 2          9      ABCA13         ATP binding cassette subfamily A member 13
# 3          9       ABCA7  ATP-binding cassette, sub-family A (ABC1), mem...
# 4          9         ACE                    angiotensin I converting enzyme
# ...      ...         ...                                                ...
# 1018       9       ZMYM2                  zinc finger MYM-type containing 2
# 1019       9      ZMYND8                 zinc finger MYND-type containing 8
# 1020       9      ZNF827                            Zinc finger protein 827
# 1021       9      ZSWIM6                 zinc finger SWIM-type containing 6
# 1022       9      ZWILCH                          zwilchkinetochore protein
#
#            ensembl-id chromosome  \
# 0     ENSG00000183044         16
# 1     ENSG00000154263         17
# 2     ENSG00000179869          7
# 3     ENSG00000064687         19
# 4     ENSG00000159640         17
# ...               ...        ...
# 1018  ENSG00000121741         13
# 1019  ENSG00000101040         20
# 1020  ENSG00000151612          4
# 1021  ENSG00000130449          5
# 1022  ENSG00000174442         15
#
#                                     genetic-category  gene-score  syndromic  \
# 0     Rare Single Gene Mutation, Genetic Association         3.0          0
# 1                          Rare Single Gene Mutation         3.0          0
# 2              Rare Single Gene Mutation, Functional         3.0          0
# 3                          Rare Single Gene Mutation         3.0          0
# 4     Rare Single Gene Mutation, Genetic Association         3.0          0
# ...                                              ...         ...        ...
# 1018            Rare Single Gene Mutation, Syndromic         2.0          1
# 1019                       Rare Single Gene Mutation         1.0          0
# 1020                             Genetic Association         3.0          0
# 1021                  Syndromic, Genetic Association         NaN          1
# 1022                       Rare Single Gene Mutation         3.0          0
#
#       number-of-reports
# 0                     5
# 1                     1
# 2                     6
# 3                     4
# 4                     3
# ...                 ...
# 1018                  6
# 1019                  4
# 1020                  1
# 1021                  3
# 1022                  4
#
# [1023 rows x 9 columns]

# %% [markdown]
# # task 1

# %%
gene_cats_data = data['genetic-category']
gene_cat_counts = gene_cats_data.value_counts()
gene_cat_vals = gene_cat_counts.index

A, B = gene_cat_vals.size, gene_cat_counts.size
assert(A == B)

plt.barh(gene_cat_vals, gene_cat_counts)
plt.xlabel("# genes")
plt.ylabel("Genetic ")
plt.title("A bar chart to show the number of genes in each\nSFARI gene-score category")
# Out:
# Text(0.5, 1.0, 'A bar chart to show the number of genes in each\nSFARI gene-score category')

# %%
gene_cats_data = data['gene-score']
gene_cat_counts = gene_cats_data.value_counts()
gene_cat_vals = gene_cat_counts.index

A, B = gene_cat_vals.size, gene_cat_counts.size
assert(A == B)

fig = plt.figure()
plt.bar(gene_cat_vals, gene_cat_counts)
plt.ylabel("# genes")
plt.xlabel("Gene score ")
plt.xticks(gene_cat_vals)
plt.title("A bar chart to show the number of SFARI\ngenes in each gene-score category")
fig.savefig(f'{os.getcwd()}/results/task1-1.pdf', dpi=fig.dpi)

# %%
gene_cat_vals
# Out:
# array([ 3.,  2.,  1., nan])

# %%
gene_cats_data = data.sort_values("gene-score")['gene-score']
gene_cat_vals = gene_cats_data.unique()
gene_cat_counts = []
for g in gene_cat_vals:
    if np.isnan(g):
        score_indexes = gene_cats_data[gene_cats_data.isnull()].index
    else:
        score_indexes = gene_cats_data[gene_cats_data == g].index
    gene_cat_counts.append(score_indexes.size)
    

A, B = gene_cat_vals.size, len(gene_cat_counts)
assert(A == B)

ticks = np.arange(gene_cat_vals.size)
tick_vals = ["1", "2", "3", "NaN"]#[str(int(val)) for val in gene_cat_vals]
print(tick_vals)

fig = plt.figure()
plt.bar(ticks, gene_cat_counts)
plt.ylabel("# genes")
plt.xlabel("Gene score ")
plt.xticks(ticks, tick_vals)
plt.title("A bar chart to show the number of SFARI\ngenes in each gene-score category")
fig.savefig(f'{os.getcwd()}/results/task1-1-v2.pdf', dpi=fig.dpi)
# Out:
# ['1', '2', '3', 'NaN']

# %% [markdown]
# # task 2

# %%
ranked_data = data.sort_values("number-of-reports")
indexes = ranked_data.index[ranked_data['gene-score'] == 1].tolist()
gene_scores = ranked_data['gene-score']
num_reports = ranked_data["number-of-reports"]

display(ranked_data)
# Out:
#      status gene-symbol                                          gene-name  \
# 511       9        KNG1                                        kininogen 1
# 574       9         MNT              MAX network transcriptional repressor
# 923       9       TFB2M             transcription factor B2, mitochondrial
# 562       9        NEO1                                         Neogenin 1
# 925       9     TMEM134                          transmembrane protein 134
# ..      ...         ...                                                ...
# 184       9     CNTNAP2                contactin associated protein-like 2
# 789       9       SCN2A  sodium channel, voltage-gated, type II, alpha ...
# 510       9       MECP2                       Methyl CpG binding protein 2
# 812       9      SHANK3          SH3 and multiple ankyrin repeat domains 3
# 596       9       NRXN1                                         neurexin 1
#
#           ensembl-id chromosome  \
# 511  ENSG00000113889          3
# 574  ENSG00000070444         17
# 923  ENSG00000162851          1
# 562  ENSG00000067141         15
# 925  ENSG00000172663         11
# ..               ...        ...
# 184  ENSG00000174469          7
# 789  ENSG00000136531          2
# 510  ENSG00000169057          X
# 812  ENSG00000251322         22
# 596  ENSG00000179915          2
#
#                                       genetic-category  gene-score  syndromic  \
# 511                          Rare Single Gene Mutation         3.0          0
# 574                                Genetic Association         3.0          0
# 923                          Rare Single Gene Mutation         3.0          0
# 562                                                NaN         3.0          0
# 925                          Rare Single Gene Mutation         3.0          0
# ..                                                 ...         ...        ...
# 184  Rare Single Gene Mutation, Syndromic, Genetic ...         2.0          1
# 789               Rare Single Gene Mutation, Syndromic         1.0          0
# 510   Rare Single Gene Mutation, Syndromic, Functional         1.0          1
# 812  Rare Single Gene Mutation, Syndromic, Genetic ...         1.0          1
# 596  Rare Single Gene Mutation, Syndromic, Genetic ...         1.0          0
#
#      number-of-reports
# 511                  1
# 574                  1
# 923                  1
# 562                  1
# 925                  1
# ..                 ...
# 184                 71
# 789                 75
# 510                 90
# 812                 92
# 596                 94
#
# [1023 rows x 9 columns]

# %%
gs = data["gene-symbol"]
data.iloc[gs[gs == "RP11-1407O15.2"].index[0]]
# Out:
# status                                       9
# gene-symbol                     RP11-1407O15.2
# gene-name                                  NaN
# ensembl-id                                 NaN
# chromosome                                  17
# genetic-category     Rare Single Gene Mutation
# gene-score                                 3.0
# syndromic                                    0
# number-of-reports                            1
# Name: 771, dtype: object

# %%
indexes[-5:]
# Out:
# [780, 789, 510, 812, 596]

# %%
for i in indexes[-5:]:
    print(i)
    print(data.iloc[i]["number-of-reports"])
    print()
# Out:
# 780
# 68
#
# 789
# 75
#
# 510
# 90
#
# 812
# 92
#
# 596
# 94

# %% [markdown]
# # task 3

# %%
# this task was completed manually
# Out:
# 1023

# %% [markdown]
# # task 4

# %%
genes = ["NRXN1", "SHANK3", "MECP2", "SCN2A", "SCN1A"]
files = ["nrxn1", "shank3", "mecp2", "scn2a", "scn1a"]

# %%
# Getting gene-names and ensemblIDs for the above genes^

# %%
gs = data["gene-symbol"]
ensembls = []
names = []

for g in genes:
    idx = gs[gs == g].index[0]
    ensembls.append(data["ensembl-id"].iloc[idx])
    names.append(data["gene-name"].iloc[idx])

# %%
# load data dynamically from NCBI

# %%
Entrez.email = "s1803764@ed.ac.uk"
all_dates = []

for j, g in tqdm(enumerate(genes)):
    handle = Entrez.esearch(db="pubmed",retmax=10000, term=f"({g}[TW] OR {names[j]}[TW] OR {ensembls[j]}[TW]) AND (autism[MH] OR autistic[MH] OR ASD[TW] OR \"autism spectrum disorder\"[TW] OR \"pervasive developmental disorder\"[TW] OR PDD-NOS[TW] OR PDD[TW] OR asperger[MH])")
    record = Entrez.read(handle)
    ids = list(set(record["IdList"]))

    dates = []
    for i in tqdm(ids):
        handle2 = Entrez.esummary(db="pubmed", retmax=10000, id=i)
        meta_data = Entrez.read(handle2)[0]
        dates.append(meta_data["PubDate"][0:4])

    all_dates.append(dates)

# %%
# load data manually from CSVs

# %%
years = np.concatenate(([1993], np.arange(1999,2022, 1)))
year_data = np.zeros((5, years.size))


for f in range(5):
    file = files[f]
    
    gene_data = pd.read_csv(os.getcwd() + "/data/task1-4/" + file + ".csv")
    year_data_f = gene_data["Publication Year"].value_counts().sort_index()
    
    for y in range(years.size):
        year = years[y]
        
        if year in year_data_f.index:
            year_data[f, y] = year_data_f[year]

# %%
year_data2 = []
#citation_data = []
#pmids = []

for f in range(5):
    file = files[f]
    
    gene_data = pd.read_csv(os.getcwd() + "/data/task1-4/" + file + ".csv")
    year_data2.append(gene_data["Publication Year"].values.tolist())
    #citation_data.append(gene_data["Citation"].values.size)
    #pmids.append(gene_data["PMID"].values.tolist())

# %%
from collections import Counter

min_date = 2021

for i, el in enumerate(all_dates):
    all_dates[i] = list(map(int, el))
    print(genes[i])
    print(len(el))
    print(Counter(el))
    if len(el) > 0:
        if np.min(all_dates[i]) < min_date:
            min_date = np.min(all_dates[i])
    print()
print(min_date)
# Out:
# NRXN1
# 119
# Counter({'2019': 15, '2012': 12, '2021': 10, '2015': 10, '2014': 10, '2013': 10, '2009': 10, '2020': 8, '2011': 8, '2018': 7, '2017': 5, '2008': 5, '2010': 4, '2016': 3, '2007': 1, '2004': 1})
#
# SHANK3
# 331
# Counter({'2021': 49, '2020': 44, '2019': 39, '2018': 38, '2016': 31, '2017': 29, '2015': 22, '2014': 21, '2011': 13, '2013': 12, '2012': 12, '2009': 8, '2008': 5, '2007': 4, '2010': 2, '1993': 1, '2005': 1})
#
# MECP2
# 261
# Counter({'2016': 29, '2011': 21, '2019': 18, '2014': 18, '2017': 17, '2020': 16, '2015': 14, '2012': 14, '2018': 13, '2010': 13, '2009': 13, '2021': 12, '2013': 12, '2008': 12, '2007': 11, '2005': 8, '2004': 5, '2003': 5, '2006': 4, '2002': 2, '2000': 2, '1993': 1, '2001': 1})
#
# SCN2A
# 64
# Counter({'2021': 14, '2019': 13, '2020': 8, '2018': 6, '2017': 5, '2016': 5, '2015': 2, '2014': 2, '2013': 2, '2008': 2, '2004': 2, '2012': 1, '2010': 1, '2003': 1})
#
# SCN1A
# 40
# Counter({'2021': 7, '2020': 5, '2012': 5, '2019': 4, '2018': 4, '2013': 3, '2016': 2, '2015': 2, '2004': 2, '1993': 1, '2011': 1, '2009': 1, '2008': 1, '2005': 1, '2003': 1})
#
# 1993

# %%
from collections import Counter

for i, el in enumerate(all_dates):
    all_dates[i] = list(map(int, el))
    print(genes[i])
    print(len(el))
    print(Counter(el))
    print()
# Out:
# NRXN1
# 76
# Counter({'2019': 9, '2012': 9, '2015': 7, '2013': 7, '2009': 7, '2021': 6, '2014': 6, '2011': 6, '2020': 5, '2017': 4, '2018': 2, '2016': 2, '2010': 2, '2008': 2, '2007': 1, '2004': 1})
#
# SHANK3
# 216
# Counter({'2020': 29, '2018': 26, '2019': 20, '2021': 19, '2017': 19, '2016': 19, '2015': 17, '2014': 17, '2013': 12, '2011': 11, '2012': 9, '2009': 8, '2008': 4, '2010': 3, '2007': 3})
#
# MECP2
# 148
# Counter({'2016': 14, '2015': 12, '2013': 11, '2011': 10, '2020': 9, '2017': 9, '2019': 8, '2014': 8, '2009': 8, '2021': 7, '2008': 7, '2005': 7, '2018': 6, '2012': 6, '2010': 5, '2007': 5, '2004': 4, '2003': 4, '2006': 3, '2002': 2, '2000': 2, '2001': 1})
#
# SCN2A
# 41
# Counter({'2021': 7, '2019': 6, '2017': 5, '2020': 4, '2018': 4, '2016': 3, '2015': 2, '2014': 2, '2013': 2, '2008': 2, '2012': 1, '2010': 1, '2004': 1, '2003': 1})
#
# SCN1A
# 19
# Counter({'2018': 3, '2012': 3, '2020': 2, '2013': 2, '2021': 1, '2019': 1, '2016': 1, '2015': 1, '2011': 1, '2009': 1, '2008': 1, '2004': 1, '2003': 1})

# %% [markdown]
# # Task 5

# %%
ax = plt.subplot()

width = 1
offsets = [-width*2, -width, 0, width, width*2]
colours = ["b", "g", "r", "c", "m"]
new_years = years*6
labels = np.char.mod("%d", years)

for f in range(5):
    ax.bar(new_years + offsets[f], year_data[f, :] + offsets[f], width=width, color=colours[f], align="center", label=genes[f])
    #print(new_years + offsets[f])
    
ax.set_xticks(new_years)
ax.set_xticklabels(labels, rotation=90)
#ax.figure.set_figheight(8)
ax.figure.set_figwidth(10)
ax.legend()

# %%
n_bins = years.size
#fcs = [(1,0,0,0.5), (0,1,0,0.5), (0,0,1,0.5), (0.5,0.5,0,0.5), (0.5,0,0.5,0.5)]

fig = plt.figure(figsize=(8,6))
plt.hist(year_data2, range(1993,2023), density=0, histtype="bar", stacked=True,color=colours, alpha=0.8, label=genes)
plt.legend()
plt.xticks(years+0.5, years, rotation=90)
plt.title("A stacked histogram to show the number of ASD-related PubMed papers\npublished each year for the top 5 reported gene-score 1 SFARI genes", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("# papers published", fontsize=12)
#fig.savefig(f'{os.getcwd()}/results/task1-5-stacked.pdf', dpi=fig.dpi)
# Out:
# Text(0, 0.5, '# papers published')

# %%
Entrez.email = "s1803764@ed.ac.uk"
num_pubs = []

for g in tqdm(gene_symbols):
    handle = Entrez.esearch(db="pubmed",retmax=2000, term=f"({g}) AND (ASD)")
    record = Entrez.read(handle)
    num_pubs.append(len(record["IdList"]))
# Out:
# 100%|███████████████████████████████████████| 1023/1023 [10:29<00:00,  1.63it/s]

# %%
years = np.arange(2000,2022)
year_labels = np.insert(years, 0, 1993)
year_range = np.arange(1993,2023)
n_bins = year_labels.size
#fcs = [(1,0,0,0.5), (0,1,0,0.5), (0,0,1,0.5), (0.5,0.5,0,0.5), (0.5,0,0.5,0.5)]

fig = plt.figure(figsize=(8,6))
plt.hist(all_dates, year_range, density=0, histtype="bar", stacked=True, color=colours, alpha=0.8, label=genes)
plt.legend()
plt.xticks(year_labels+0.5, year_labels, rotation=90)
plt.title("A stacked histogram to show the number of autism-related PubMed papers\npublished each year for the top 5 reported gene-score 1 SFARI genes", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("# papers published", fontsize=12)
#fig.savefig(f'{os.getcwd()}/results/task1-5-stacked.pdf', dpi=fig.dpi)
# Out:
# Text(0, 0.5, '# papers published')

# %% [markdown]
# # Extension

# %%
gs = data["gene-symbol"]
ensembls = []
names = []

for g in gene_symbols:
    idx = gs[gs == g].index[0]
    ensembls.append(data["ensembl-id"].iloc[idx])
    names.append(data["gene-name"].iloc[idx])

# %%
Entrez.email = "s1803764@ed.ac.uk"
all_gene_dates = []

for j, g in tqdm(enumerate(gene_symbols)):
    handle = Entrez.esearch(db="pubmed",retmax=10000, term=f"({g}[TW] OR {names[j]}[TW] OR {ensembls[j]}[TW]) AND (autism[MH] OR autistic[MH] OR ASD[TW] OR \"autism spectrum disorder\"[TW] OR \"pervasive developmental disorder\"[TW] OR PDD-NOS[TW] OR PDD[TW] OR asperger[MH])")
    record = Entrez.read(handle)
    ids = list(set(record["IdList"]))

    dates = []
    for i in tqdm(ids):
        handle2 = Entrez.esummary(db="pubmed", retmax=10000, id=i)
        meta_data = Entrez.read(handle2)[0]
        dates.append(meta_data["PubDate"][0:4])

    all_gene_dates.append(dates)
# Out:
# 0it [00:00, ?it/s]
# 1022
#   0%|                                                   | 0/290 [00:00<?, ?it/s]
#   0%|▏                                          | 1/290 [00:00<03:28,  1.39it/s]
#   1%|▎                                          | 2/290 [00:01<03:07,  1.53it/s]
#   1%|▍                                          | 3/290 [00:01<02:59,  1.60it/s]
#   1%|▌                                          | 4/290 [00:02<02:49,  1.69it/s]
#   2%|▋                                          | 5/290 [00:03<02:50,  1.67it/s]
#   2%|▉                                          | 6/290 [00:03<02:56,  1.61it/s]
#   2%|█                                          | 7/290 [00:04<03:00,  1.57it/s]
#   3%|█▏                                         | 8/290 [00:05<02:55,  1.60it/s]
#   3%|█▎                                         | 9/290 [00:05<02:52,  1.63it/s]
#   3%|█▍                                        | 10/290 [00:06<02:49,  1.65it/s]
#   4%|█▌                                        | 11/290 [00:06<02:55,  1.59it/s]
#   4%|█▋                                        | 12/290 [00:07<02:52,  1.61it/s]
#   4%|█▉                                        | 13/290 [00:08<02:46,  1.66it/s]
#   5%|██                                        | 14/290 [00:08<02:53,  1.59it/s]
#   5%|██▏                                       | 15/290 [00:09<02:53,  1.59it/s]
#   6%|██▎                                       | 16/290 [00:09<02:53,  1.58it/s]
#   6%|██▍                                       | 17/290 [00:10<02:52,  1.58it/s]
#   6%|██▌                                       | 18/290 [00:11<02:46,  1.64it/s]
#   7%|██▊                                       | 19/290 [00:11<02:44,  1.65it/s]
#   7%|██▉                                       | 20/290 [00:12<02:39,  1.69it/s]
#   7%|███                                       | 21/290 [00:13<02:46,  1.61it/s]
#   8%|███▏                                      | 22/290 [00:13<02:44,  1.63it/s]
#   8%|███▎                                      | 23/290 [00:14<03:05,  1.44it/s]
#   8%|███▍                                      | 24/290 [00:15<03:39,  1.21it/s]
#   9%|███▌                                      | 25/290 [00:16<03:27,  1.28it/s]
#   9%|███▊                                      | 26/290 [00:17<03:24,  1.29it/s]
#   9%|███▉                                      | 27/290 [00:17<03:09,  1.39it/s]
#  10%|████                                      | 28/290 [00:18<03:03,  1.43it/s]
#  10%|████▏                                     | 29/290 [00:18<02:51,  1.52it/s]
#  10%|████▎                                     | 30/290 [00:19<02:42,  1.60it/s]
#  11%|████▍                                     | 31/290 [00:20<02:45,  1.56it/s]
#  11%|████▋                                     | 32/290 [00:20<02:45,  1.56it/s]
#  11%|████▊                                     | 33/290 [00:21<02:36,  1.64it/s]
#  12%|████▉                                     | 34/290 [00:21<02:43,  1.57it/s]
#  12%|█████                                     | 35/290 [00:22<02:36,  1.63it/s]
#  12%|█████▏                                    | 36/290 [00:23<02:32,  1.67it/s]
#  13%|█████▎                                    | 37/290 [00:23<02:34,  1.64it/s]
#  13%|█████▌                                    | 38/290 [00:24<02:32,  1.65it/s]
#  13%|█████▋                                    | 39/290 [00:24<02:30,  1.67it/s]
#  14%|█████▊                                    | 40/290 [00:25<02:31,  1.65it/s]
#  14%|█████▉                                    | 41/290 [00:26<02:34,  1.61it/s]
#  14%|██████                                    | 42/290 [00:26<02:28,  1.68it/s]
#  15%|██████▏                                   | 43/290 [00:27<02:27,  1.67it/s]
#  15%|██████▎                                   | 44/290 [00:27<02:24,  1.70it/s]
#  16%|██████▌                                   | 45/290 [00:28<02:21,  1.73it/s]
#  16%|██████▋                                   | 46/290 [00:29<02:22,  1.71it/s]
#  16%|██████▊                                   | 47/290 [00:29<02:25,  1.67it/s]
#  17%|██████▉                                   | 48/290 [00:30<02:29,  1.62it/s]
#  17%|███████                                   | 49/290 [00:31<02:46,  1.44it/s]
#  17%|███████▏                                  | 50/290 [00:31<02:39,  1.50it/s]
#  18%|███████▍                                  | 51/290 [00:32<02:34,  1.55it/s]
#  18%|███████▌                                  | 52/290 [00:33<02:33,  1.55it/s]
#  18%|███████▋                                  | 53/290 [00:33<02:23,  1.65it/s]
#  19%|███████▊                                  | 54/290 [00:34<02:26,  1.61it/s]
#  19%|███████▉                                  | 55/290 [00:34<02:26,  1.61it/s]
#  19%|████████                                  | 56/290 [00:35<02:21,  1.66it/s]
#  20%|████████▎                                 | 57/290 [00:36<02:23,  1.63it/s]
#  20%|████████▍                                 | 58/290 [00:36<02:24,  1.61it/s]
#  20%|████████▌                                 | 59/290 [00:37<02:25,  1.59it/s]
#  21%|████████▋                                 | 60/290 [00:37<02:25,  1.59it/s]
#  21%|████████▊                                 | 61/290 [00:38<02:28,  1.54it/s]
#  21%|████████▉                                 | 62/290 [00:39<02:25,  1.57it/s]
#  22%|█████████                                 | 63/290 [00:39<02:23,  1.58it/s]
#  22%|█████████▎                                | 64/290 [00:40<02:20,  1.60it/s]
#  22%|█████████▍                                | 65/290 [00:41<02:14,  1.68it/s]
#  23%|█████████▌                                | 66/290 [00:41<02:12,  1.69it/s]
#  23%|█████████▋                                | 67/290 [00:42<02:15,  1.65it/s]
#  23%|█████████▊                                | 68/290 [00:42<02:12,  1.68it/s]
#  24%|█████████▉                                | 69/290 [00:43<02:09,  1.71it/s]
#  24%|██████████▏                               | 70/290 [00:43<02:07,  1.72it/s]
#  24%|██████████▎                               | 71/290 [00:44<02:05,  1.74it/s]
#  25%|██████████▍                               | 72/290 [00:45<02:10,  1.67it/s]
#  25%|██████████▌                               | 73/290 [00:45<02:12,  1.64it/s]
#  26%|██████████▋                               | 74/290 [00:46<02:12,  1.63it/s]
#  26%|██████████▊                               | 75/290 [00:47<02:10,  1.65it/s]
#  26%|███████████                               | 76/290 [00:47<02:13,  1.61it/s]
#  27%|███████████▏                              | 77/290 [00:48<02:16,  1.56it/s]
#  27%|███████████▎                              | 78/290 [00:48<02:11,  1.61it/s]
#  27%|███████████▍                              | 79/290 [00:49<02:20,  1.50it/s]
#  28%|███████████▌                              | 80/290 [00:50<02:15,  1.55it/s]
#  28%|███████████▋                              | 81/290 [00:50<02:15,  1.55it/s]
#  28%|███████████▉                              | 82/290 [00:51<02:11,  1.58it/s]
#  29%|████████████                              | 83/290 [00:52<02:07,  1.62it/s]
#  29%|████████████▏                             | 84/290 [00:52<02:11,  1.57it/s]
#  29%|████████████▎                             | 85/290 [00:53<02:05,  1.63it/s]
#  30%|████████████▍                             | 86/290 [00:53<02:02,  1.66it/s]
#  30%|████████████▌                             | 87/290 [00:54<02:01,  1.68it/s]
#  30%|████████████▋                             | 88/290 [00:55<02:03,  1.63it/s]
#  31%|████████████▉                             | 89/290 [00:55<02:01,  1.65it/s]
#  31%|█████████████                             | 90/290 [00:56<01:58,  1.69it/s]
#  31%|█████████████▏                            | 91/290 [00:56<01:58,  1.68it/s]
#  32%|█████████████▎                            | 92/290 [00:57<02:00,  1.64it/s]
#  32%|█████████████▍                            | 93/290 [00:58<02:03,  1.60it/s]
#  32%|█████████████▌                            | 94/290 [00:58<02:05,  1.56it/s]
#  33%|█████████████▊                            | 95/290 [00:59<02:00,  1.62it/s]
#  33%|█████████████▉                            | 96/290 [01:00<02:02,  1.59it/s]
#  33%|██████████████                            | 97/290 [01:00<01:58,  1.63it/s]
#  34%|██████████████▏                           | 98/290 [01:01<02:05,  1.53it/s]
#  34%|██████████████▎                           | 99/290 [01:02<02:01,  1.57it/s]
#  34%|██████████████▏                          | 100/290 [01:02<02:03,  1.53it/s]
#  35%|██████████████▎                          | 101/290 [01:03<02:02,  1.54it/s]
#  35%|██████████████▍                          | 102/290 [01:04<02:01,  1.55it/s]
#  36%|██████████████▌                          | 103/290 [01:04<01:55,  1.62it/s]
#  36%|██████████████▋                          | 104/290 [01:05<02:00,  1.54it/s]
#  36%|██████████████▊                          | 105/290 [01:05<01:55,  1.60it/s]
#  37%|██████████████▉                          | 106/290 [01:06<01:53,  1.63it/s]
#  37%|███████████████▏                         | 107/290 [01:07<01:49,  1.67it/s]
#  37%|███████████████▎                         | 108/290 [01:07<01:51,  1.64it/s]
#  38%|███████████████▍                         | 109/290 [01:08<01:46,  1.70it/s]
#  38%|███████████████▌                         | 110/290 [01:08<01:45,  1.70it/s]
#  38%|███████████████▋                         | 111/290 [01:09<01:43,  1.73it/s]
#  39%|███████████████▊                         | 112/290 [01:09<01:42,  1.74it/s]
#  39%|███████████████▉                         | 113/290 [01:10<01:48,  1.63it/s]
#  39%|████████████████                         | 114/290 [01:11<01:49,  1.60it/s]
#  40%|████████████████▎                        | 115/290 [01:11<01:45,  1.66it/s]
#  40%|████████████████▍                        | 116/290 [01:12<01:45,  1.65it/s]
#  40%|████████████████▌                        | 117/290 [01:13<01:44,  1.66it/s]
#  41%|████████████████▋                        | 118/290 [01:13<01:44,  1.65it/s]
#  41%|████████████████▊                        | 119/290 [01:14<01:40,  1.71it/s]
#  41%|████████████████▉                        | 120/290 [01:14<01:39,  1.72it/s]
#  42%|█████████████████                        | 121/290 [01:15<01:41,  1.67it/s]
#  42%|█████████████████▏                       | 122/290 [01:15<01:40,  1.67it/s]
#  42%|█████████████████▍                       | 123/290 [01:16<01:40,  1.67it/s]
#  43%|█████████████████▌                       | 124/290 [01:17<01:37,  1.71it/s]
#  43%|█████████████████▋                       | 125/290 [01:17<01:37,  1.68it/s]
#  43%|█████████████████▊                       | 126/290 [01:18<01:37,  1.67it/s]
#  44%|█████████████████▉                       | 127/290 [01:18<01:36,  1.69it/s]
#  44%|██████████████████                       | 128/290 [01:19<01:36,  1.68it/s]
#  44%|██████████████████▏                      | 129/290 [01:20<01:34,  1.71it/s]
#  45%|██████████████████▍                      | 130/290 [01:20<01:36,  1.66it/s]
#  45%|██████████████████▌                      | 131/290 [01:21<01:37,  1.63it/s]
#  46%|██████████████████▋                      | 132/290 [01:22<01:37,  1.61it/s]
#  46%|██████████████████▊                      | 133/290 [01:22<01:38,  1.59it/s]
#  46%|██████████████████▉                      | 134/290 [01:23<01:38,  1.58it/s]
#  47%|███████████████████                      | 135/290 [01:23<01:36,  1.60it/s]
#  47%|███████████████████▏                     | 136/290 [01:24<01:34,  1.63it/s]
#  47%|███████████████████▎                     | 137/290 [01:25<01:31,  1.68it/s]
#  48%|███████████████████▌                     | 138/290 [01:25<01:34,  1.61it/s]
#  48%|███████████████████▋                     | 139/290 [01:26<01:32,  1.63it/s]
#  48%|███████████████████▊                     | 140/290 [01:26<01:33,  1.60it/s]
#  49%|███████████████████▉                     | 141/290 [01:27<01:31,  1.62it/s]
#  49%|████████████████████                     | 142/290 [01:28<01:27,  1.69it/s]
#  49%|████████████████████▏                    | 143/290 [01:28<01:26,  1.70it/s]
#  50%|████████████████████▎                    | 144/290 [01:29<01:30,  1.61it/s]
#  50%|████████████████████▌                    | 145/290 [01:30<01:32,  1.58it/s]
#  50%|████████████████████▋                    | 146/290 [01:30<01:31,  1.57it/s]
#  51%|████████████████████▊                    | 147/290 [01:31<01:33,  1.53it/s]
#  51%|████████████████████▉                    | 148/290 [01:32<01:38,  1.44it/s]
#  51%|█████████████████████                    | 149/290 [01:32<01:39,  1.42it/s]
#  52%|█████████████████████▏                   | 150/290 [01:33<01:36,  1.46it/s]
#  52%|█████████████████████▎                   | 151/290 [01:34<01:32,  1.51it/s]
#  52%|█████████████████████▍                   | 152/290 [01:34<01:29,  1.54it/s]
#  53%|█████████████████████▋                   | 153/290 [01:35<01:25,  1.60it/s]
#  53%|█████████████████████▊                   | 154/290 [01:35<01:25,  1.60it/s]
#  53%|█████████████████████▉                   | 155/290 [01:36<01:25,  1.59it/s]
#  54%|██████████████████████                   | 156/290 [01:37<01:21,  1.64it/s]
#  54%|██████████████████████▏                  | 157/290 [01:37<01:20,  1.64it/s]
#  54%|██████████████████████▎                  | 158/290 [01:38<01:18,  1.69it/s]
#  55%|██████████████████████▍                  | 159/290 [01:38<01:16,  1.72it/s]
#  55%|██████████████████████▌                  | 160/290 [01:39<01:19,  1.63it/s]
#  56%|██████████████████████▊                  | 161/290 [01:40<01:20,  1.60it/s]
#  56%|██████████████████████▉                  | 162/290 [01:40<01:20,  1.60it/s]
#  56%|███████████████████████                  | 163/290 [01:41<01:18,  1.61it/s]
#  57%|███████████████████████▏                 | 164/290 [01:42<01:18,  1.60it/s]
#  57%|███████████████████████▎                 | 165/290 [01:42<01:16,  1.63it/s]
#  57%|███████████████████████▍                 | 166/290 [01:43<01:17,  1.61it/s]
#  58%|███████████████████████▌                 | 167/290 [01:43<01:14,  1.65it/s]
#  58%|███████████████████████▊                 | 168/290 [01:44<01:14,  1.65it/s]
#  58%|███████████████████████▉                 | 169/290 [01:45<01:13,  1.64it/s]
#  59%|████████████████████████                 | 170/290 [01:45<01:12,  1.67it/s]
#  59%|████████████████████████▏                | 171/290 [01:46<01:11,  1.66it/s]
#  59%|████████████████████████▎                | 172/290 [01:46<01:10,  1.66it/s]
#  60%|████████████████████████▍                | 173/290 [01:47<01:08,  1.71it/s]
#  60%|████████████████████████▌                | 174/290 [01:48<01:09,  1.67it/s]
#  60%|████████████████████████▋                | 175/290 [01:48<01:07,  1.71it/s]
#  61%|████████████████████████▉                | 176/290 [01:49<01:07,  1.69it/s]
#  61%|█████████████████████████                | 177/290 [01:49<01:05,  1.72it/s]
#  61%|█████████████████████████▏               | 178/290 [01:50<01:07,  1.66it/s]
#  62%|█████████████████████████▎               | 179/290 [01:51<01:05,  1.70it/s]
#  62%|█████████████████████████▍               | 180/290 [01:51<01:03,  1.72it/s]
#  62%|█████████████████████████▌               | 181/290 [01:52<01:20,  1.35it/s]
#  63%|█████████████████████████▋               | 182/290 [01:53<01:17,  1.39it/s]
#  63%|█████████████████████████▊               | 183/290 [01:53<01:11,  1.49it/s]
#  63%|██████████████████████████               | 184/290 [01:54<01:09,  1.53it/s]
#  64%|██████████████████████████▏              | 185/290 [01:55<01:06,  1.57it/s]
#  64%|██████████████████████████▎              | 186/290 [01:55<01:05,  1.59it/s]
#  64%|██████████████████████████▍              | 187/290 [01:56<01:04,  1.59it/s]
#  65%|██████████████████████████▌              | 188/290 [01:57<01:04,  1.57it/s]
#  65%|██████████████████████████▋              | 189/290 [01:57<01:02,  1.61it/s]
#  66%|██████████████████████████▊              | 190/290 [01:58<01:00,  1.65it/s]
#  66%|███████████████████████████              | 191/290 [01:58<00:58,  1.69it/s]
#  66%|███████████████████████████▏             | 192/290 [01:59<01:01,  1.58it/s]
#  67%|███████████████████████████▎             | 193/290 [02:00<01:01,  1.57it/s]
#  67%|███████████████████████████▍             | 194/290 [02:00<00:58,  1.63it/s]
#  67%|███████████████████████████▌             | 195/290 [02:01<00:56,  1.67it/s]
#  68%|███████████████████████████▋             | 196/290 [02:01<00:56,  1.65it/s]
#  68%|███████████████████████████▊             | 197/290 [02:02<00:56,  1.65it/s]
#  68%|███████████████████████████▉             | 198/290 [02:03<00:55,  1.66it/s]
#  69%|████████████████████████████▏            | 199/290 [02:03<01:01,  1.47it/s]
#  69%|████████████████████████████▎            | 200/290 [02:04<00:58,  1.54it/s]
#  69%|████████████████████████████▍            | 201/290 [02:05<00:56,  1.58it/s]
#  70%|████████████████████████████▌            | 202/290 [02:05<00:58,  1.51it/s]
#  70%|████████████████████████████▋            | 203/290 [02:06<00:56,  1.53it/s]
#  70%|████████████████████████████▊            | 204/290 [02:07<00:55,  1.56it/s]
#  71%|████████████████████████████▉            | 205/290 [02:07<00:54,  1.56it/s]
#  71%|█████████████████████████████            | 206/290 [02:08<00:52,  1.59it/s]
#  71%|█████████████████████████████▎           | 207/290 [02:08<00:51,  1.62it/s]
#  72%|█████████████████████████████▍           | 208/290 [02:09<00:49,  1.67it/s]
#  72%|█████████████████████████████▌           | 209/290 [02:10<00:47,  1.70it/s]
#  72%|█████████████████████████████▋           | 210/290 [02:10<00:46,  1.73it/s]
#  73%|█████████████████████████████▊           | 211/290 [02:11<00:46,  1.71it/s]
#  73%|█████████████████████████████▉           | 212/290 [02:11<00:44,  1.73it/s]
#  73%|██████████████████████████████           | 213/290 [02:12<00:45,  1.68it/s]
#  74%|██████████████████████████████▎          | 214/290 [02:12<00:45,  1.67it/s]
#  74%|██████████████████████████████▍          | 215/290 [02:13<00:46,  1.61it/s]
#  74%|██████████████████████████████▌          | 216/290 [02:14<00:45,  1.62it/s]
#  75%|██████████████████████████████▋          | 217/290 [02:14<00:44,  1.63it/s]
#  75%|██████████████████████████████▊          | 218/290 [02:15<00:43,  1.65it/s]
#  76%|██████████████████████████████▉          | 219/290 [02:16<00:41,  1.70it/s]
#  76%|███████████████████████████████          | 220/290 [02:16<00:41,  1.68it/s]
#  76%|███████████████████████████████▏         | 221/290 [02:17<00:42,  1.63it/s]
#  77%|███████████████████████████████▍         | 222/290 [02:17<00:40,  1.68it/s]
#  77%|███████████████████████████████▌         | 223/290 [02:18<00:38,  1.72it/s]
#  77%|███████████████████████████████▋         | 224/290 [02:18<00:38,  1.74it/s]
#  78%|███████████████████████████████▊         | 225/290 [02:19<00:37,  1.75it/s]
#  78%|███████████████████████████████▉         | 226/290 [02:20<00:36,  1.75it/s]
#  78%|████████████████████████████████         | 227/290 [02:20<00:35,  1.75it/s]
#  79%|████████████████████████████████▏        | 228/290 [02:21<00:35,  1.75it/s]
#  79%|████████████████████████████████▍        | 229/290 [02:21<00:36,  1.68it/s]
#  79%|████████████████████████████████▌        | 230/290 [02:22<00:36,  1.65it/s]
#  80%|████████████████████████████████▋        | 231/290 [02:23<00:36,  1.63it/s]
#  80%|████████████████████████████████▊        | 232/290 [02:23<00:35,  1.63it/s]
#  80%|████████████████████████████████▉        | 233/290 [02:24<00:34,  1.67it/s]
#  81%|█████████████████████████████████        | 234/290 [02:24<00:33,  1.67it/s]
#  81%|█████████████████████████████████▏       | 235/290 [02:25<00:32,  1.70it/s]
#  81%|█████████████████████████████████▎       | 236/290 [02:26<00:32,  1.65it/s]
#  82%|█████████████████████████████████▌       | 237/290 [02:26<00:31,  1.67it/s]
#  82%|█████████████████████████████████▋       | 238/290 [02:27<00:31,  1.66it/s]
#  82%|█████████████████████████████████▊       | 239/290 [02:28<00:32,  1.58it/s]
#  83%|█████████████████████████████████▉       | 240/290 [02:28<00:31,  1.60it/s]
#  83%|██████████████████████████████████       | 241/290 [02:29<00:30,  1.59it/s]
#  83%|██████████████████████████████████▏      | 242/290 [02:29<00:31,  1.55it/s]
#  84%|██████████████████████████████████▎      | 243/290 [02:30<00:29,  1.60it/s]
#  84%|██████████████████████████████████▍      | 244/290 [02:31<00:28,  1.64it/s]
#  84%|██████████████████████████████████▋      | 245/290 [02:31<00:26,  1.67it/s]
#  85%|██████████████████████████████████▊      | 246/290 [02:32<00:25,  1.71it/s]
#  85%|██████████████████████████████████▉      | 247/290 [02:32<00:25,  1.70it/s]
#  86%|███████████████████████████████████      | 248/290 [02:33<00:24,  1.71it/s]
#  86%|███████████████████████████████████▏     | 249/290 [02:34<00:25,  1.60it/s]
#  86%|███████████████████████████████████▎     | 250/290 [02:34<00:25,  1.59it/s]
#  87%|███████████████████████████████████▍     | 251/290 [02:35<00:24,  1.58it/s]
#  87%|███████████████████████████████████▋     | 252/290 [02:36<00:25,  1.50it/s]
#  87%|███████████████████████████████████▊     | 253/290 [02:36<00:24,  1.49it/s]
#  88%|███████████████████████████████████▉     | 254/290 [02:37<00:23,  1.54it/s]
#  88%|████████████████████████████████████     | 255/290 [02:38<00:22,  1.58it/s]
#  88%|████████████████████████████████████▏    | 256/290 [02:38<00:21,  1.59it/s]
#  89%|████████████████████████████████████▎    | 257/290 [02:39<00:20,  1.59it/s]
#  89%|████████████████████████████████████▍    | 258/290 [02:39<00:19,  1.61it/s]
#  89%|████████████████████████████████████▌    | 259/290 [02:40<00:18,  1.67it/s]
#  90%|████████████████████████████████████▊    | 260/290 [02:41<00:18,  1.60it/s]
#  90%|████████████████████████████████████▉    | 261/290 [02:41<00:18,  1.55it/s]
#  90%|█████████████████████████████████████    | 262/290 [02:42<00:17,  1.56it/s]
#  91%|█████████████████████████████████████▏   | 263/290 [02:42<00:16,  1.62it/s]
#  91%|█████████████████████████████████████▎   | 264/290 [02:43<00:15,  1.64it/s]
#  91%|█████████████████████████████████████▍   | 265/290 [02:44<00:14,  1.68it/s]
#  92%|█████████████████████████████████████▌   | 266/290 [02:44<00:14,  1.64it/s]
#  92%|█████████████████████████████████████▋   | 267/290 [02:45<00:13,  1.72it/s]
#  92%|█████████████████████████████████████▉   | 268/290 [02:45<00:12,  1.70it/s]
#  93%|██████████████████████████████████████   | 269/290 [02:46<00:12,  1.65it/s]
#  93%|██████████████████████████████████████▏  | 270/290 [02:47<00:12,  1.67it/s]
#  93%|██████████████████████████████████████▎  | 271/290 [02:47<00:11,  1.66it/s]
#  94%|██████████████████████████████████████▍  | 272/290 [02:48<00:10,  1.67it/s]
#  94%|██████████████████████████████████████▌  | 273/290 [02:48<00:10,  1.67it/s]
#  94%|██████████████████████████████████████▋  | 274/290 [02:49<00:09,  1.66it/s]
#  95%|██████████████████████████████████████▉  | 275/290 [02:50<00:08,  1.67it/s]
#  95%|███████████████████████████████████████  | 276/290 [02:50<00:08,  1.66it/s]
#  96%|███████████████████████████████████████▏ | 277/290 [02:51<00:07,  1.67it/s]
#  96%|███████████████████████████████████████▎ | 278/290 [02:51<00:07,  1.70it/s]
#  96%|███████████████████████████████████████▍ | 279/290 [02:52<00:06,  1.73it/s]
#  97%|███████████████████████████████████████▌ | 280/290 [02:53<00:05,  1.71it/s]
#  97%|███████████████████████████████████████▋ | 281/290 [02:53<00:05,  1.66it/s]
#  97%|███████████████████████████████████████▊ | 282/290 [02:54<00:04,  1.63it/s]
#  98%|████████████████████████████████████████ | 283/290 [02:55<00:04,  1.57it/s]
#  98%|████████████████████████████████████████▏| 284/290 [02:55<00:03,  1.56it/s]
#  98%|████████████████████████████████████████▎| 285/290 [02:56<00:03,  1.55it/s]
#  99%|████████████████████████████████████████▍| 286/290 [02:57<00:02,  1.52it/s]
#  99%|████████████████████████████████████████▌| 287/290 [02:57<00:01,  1.54it/s]
#  99%|████████████████████████████████████████▋| 288/290 [02:58<00:01,  1.55it/s]
# 100%|████████████████████████████████████████▊| 289/290 [02:58<00:00,  1.57it/s]
# 100%|█████████████████████████████████████████| 290/290 [02:59<00:00,  1.62it/s]
# 1it [03:00, 180.78s/it]

# %%
from collections import Counter

min_date = 2021

for i, el in enumerate(all_gene_dates):
    all_gene_dates[i] = list(map(int, el))
    print(gene_symbols[i])
    print(len(el))
    print(Counter(el))
    if len(el) > 0:
        if np.min(all_gene_dates[i]) < min_date:
            min_date = np.min(all_gene_dates[i])
    print()
print(min_date)
# Out:
# ABAT
# 4
# Counter({'2005': 1, '2018': 1, '2012': 1, '2017': 1})
#
# ABCA10
# 0
# Counter()
#
# ABCA13
# 4
# Counter({'2018': 2, '2020': 1, '2016': 1})
#
# ABCA7
# 0
# Counter()
#
# ACE
# 24
# Counter({'2021': 5, '2020': 5, '2019': 3, '2016': 2, '2010': 2, '2014': 2, '2017': 1, '2018': 1, '1998': 1, '2012': 1, '2015': 1})
#
# ACHE
# 0
# Counter()
#
# ACTB
# 2
# Counter({'2019': 1, '2016': 1})
#
# ACTL6B
# 5
# Counter({'2020': 2, '2019': 1, '2017': 1, '2014': 1})
#
# ACTN4
# 1
# Counter({'2018': 1})
#
# ACY1
# 1
# Counter({'2010': 1})
#
# ADA
# 13
# Counter({'2013': 3, '2019': 2, '2000': 1, '1982': 1, '2020': 1, '2011': 1, '2004': 1, '2002': 1, '2008': 1, '2001': 1})
#
# ADCY3
# 1
# Counter({'2019': 1})
#
# ADCY5
# 1
# Counter({'2017': 1})
#
# ADK
# 0
# Counter()
#
# ADNP
# 42
# Counter({'2019': 7, '2020': 7, '2021': 7, '2018': 7, '2016': 4, '2017': 4, '2015': 3, '2014': 2, '1993': 1})
#
# ADORA3
# 2
# Counter({'2011': 1, '2013': 1})
#
# ADSL
# 47
# Counter({'2013': 6, '2012': 5, '1989': 4, '2021': 3, '2000': 3, '2015': 3, '2017': 2, '1986': 2, '2020': 2, '2011': 2, '2004': 2, '2019': 1, '2009': 1, '2018': 1, '1996': 1, '2014': 1, '2016': 1, '1995': 1, '2010': 1, '1999': 1, '2005': 1, '2008': 1, '1984': 1, '1992': 1})
#
# AFF2
# 9
# Counter({'2018': 2, '2015': 2, '2016': 1, '2012': 1, '2020': 1, '2011': 1, '2013': 1})
#
# AGAP1
# 3
# Counter({'2005': 1, '2016': 1, '2019': 1})
#
# AGAP2
# 0
# Counter()
#
# ADSS2
# 0
# Counter()
#
# AGBL4
# 0
# Counter()
#
# AGMO
# 1
# Counter({'2016': 1})
#
# AGO1
# 3
# Counter({'2018': 1, '2019': 1, '2021': 1})
#
# AGO3
# 0
# Counter()
#
# AGO4
# 0
# Counter()
#
# AGTR2
# 2
# Counter({'2019': 1, '2012': 1})
#
# AHDC1
# 2
# Counter({'2018': 1, '2021': 1})
#
# AHI1
# 4
# Counter({'2008': 1, '2014': 1, '2012': 1, '2020': 1})
#
# AKAP9
# 0
# Counter()
#
# ALDH1A3
# 3
# Counter({'2021': 1, '2014': 1, '2015': 1})
#
# ALDH5A1
# 0
# Counter()
#
# AMPD1
# 2
# Counter({'2014': 1, '2015': 1})
#
# AMT
# 7
# Counter({'2019': 2, '2013': 1, '2001': 1, '2020': 1, '2005': 1, '2018': 1})
#
# ANK2
# 8
# Counter({'2020': 3, '2021': 3, '2019': 2})
#
# ANK3
# 12
# Counter({'2020': 2, '2012': 2, '2015': 2, '2016': 1, '2017': 1, '2014': 1, '2021': 1, '2019': 1, '2018': 1})
#
# ANKRD11
# 14
# Counter({'2015': 3, '2021': 3, '2017': 2, '2019': 1, '2013': 1, '2010': 1, '2014': 1, '2018': 1, '2008': 1})
#
# AGAP5
# 0
# Counter()
#
# AGO2
# 0
# Counter()
#
# AHNAK
# 0
# Counter()
#
# ANKRD17
# 0
# Counter()
#
# ANKS1B
# 2
# Counter({'2019': 1, '2020': 1})
#
# ANXA1
# 1
# Counter({'2014': 1})
#
# AP1S2
# 1
# Counter({'2019': 1})
#
# APBA2
# 0
# Counter()
#
# APBB1
# 2
# Counter({'2014': 1, '2021': 1})
#
# APH1A
# 0
# Counter()
#
# ARHGAP11B
# 2
# Counter({'2013': 1, '2019': 1})
#
# ARHGAP32
# 3
# Counter({'2019': 1, '2016': 1, '2015': 1})
#
# ARHGAP5
# 0
# Counter()
#
# ARHGEF10
# 4
# Counter({'2017': 1, '2009': 1, '2021': 1, '2018': 1})
#
# ARHGEF9
# 0
# Counter()
#
# ARID1B
# 25
# Counter({'2021': 7, '2020': 5, '2017': 5, '2018': 2, '2019': 2, '2016': 1, '2011': 1, '2012': 1, '2015': 1})
#
# ARID2
# 1
# Counter({'2017': 1})
#
# ARNT2
# 2
# Counter({'2014': 2})
#
# ARX
# 15
# Counter({'2014': 3, '2002': 2, '2008': 2, '2021': 1, '2010': 1, '2020': 1, '2003': 1, '2011': 1, '2007': 1, '2005': 1, '2019': 1})
#
# ASAP2
# 0
# Counter()
#
# ASB14
# 0
# Counter()
#
# ASH1L
# 0
# Counter()
#
# ASMT
# 13
# Counter({'2013': 2, '2008': 2, '2017': 2, '2011': 1, '2018': 1, '2021': 1, '2014': 1, '2010': 1, '2015': 1, '2007': 1})
#
# ASPM
# 3
# Counter({'2020': 1, '2009': 1, '2018': 1})
#
# ASTN2
# 10
# Counter({'2016': 3, '2018': 2, '2017': 1, '2021': 1, '2009': 1, '2011': 1, '2014': 1})
#
# ASXL3
# 0
# Counter()
#
# ATP10A
# 6
# Counter({'2008': 3, '2002': 1, '2020': 1, '2011': 1})
#
# ATP1A1
# 0
# Counter()
#
# ATP1A3
# 5
# Counter({'2018': 2, '2017': 1, '2021': 1, '2019': 1})
#
# ATP2B2
# 7
# Counter({'2017': 1, '2014': 1, '2011': 1, '2013': 1, '2018': 1, '2020': 1, '2012': 1})
#
# ATP6V0A2
# 0
# Counter()
#
# ATRX
# 8
# Counter({'2019': 2, '2020': 2, '2018': 1, '2014': 1, '2008': 1, '2013': 1})
#
# AUTS2
# 35
# Counter({'2019': 6, '2021': 4, '2011': 4, '2014': 4, '2013': 3, '2015': 3, '2016': 2, '2010': 2, '2017': 1, '2008': 1, '2012': 1, '2007': 1, '2002': 1, '2006': 1, '2020': 1})
#
# ADORA2A
# 12
# Counter({'2017': 4, '2018': 4, '2019': 1, '2020': 1, '2014': 1, '2010': 1})
#
# AP2S1
# 0
# Counter()
#
# AVPR1A
# 26
# Counter({'2017': 5, '2018': 4, '2015': 3, '2019': 2, '2006': 2, '2016': 2, '2008': 2, '2010': 1, '2004': 1, '2009': 1, '2012': 1, '2021': 1, '2002': 1})
#
# AZGP1
# 0
# Counter()
#
# BAZ2B
# 3
# Counter({'2017': 2, '2020': 1})
#
# BBS4
# 0
# Counter()
#
# BCAS1
# 0
# Counter()
#
# BCKDK
# 5
# Counter({'2013': 2, '2012': 1, '2019': 1, '2016': 1})
#
# BCL11A
# 0
# Counter()
#
# ADRB2
# 2
# Counter({'2007': 1, '2009': 1})
#
# ALG6
# 1
# Counter({'2020': 1})
#
# AR
# 60
# Counter({'2017': 5, '2018': 5, '2012': 5, '2013': 5, '2015': 4, '2020': 4, '2019': 4, '2004': 3, '2010': 3, '1982': 3, '2009': 2, '2016': 2, '2008': 2, '1992': 1, '2007': 1, '1987': 1, '2021': 1, '1981': 1, '2005': 1, '2014': 1, '2001': 1, '2002': 1, '1994': 1, '1985': 1, '2006': 1, '2011': 1})
#
# AVPR1B
# 4
# Counter({'2018': 1, '2016': 1, '2009': 1, '2012': 1})
#
# BCORL1
# 0
# Counter()
#
# BIRC6
# 3
# Counter({'2021': 1, '2019': 1, '2020': 1})
#
# BRAF
# 1
# Counter({'2020': 1})
#
# BRCA2
# 1
# Counter({'2015': 1})
#
# BRD4
# 3
# Counter({'2021': 1, '2019': 1, '2020': 1})
#
# BRSK2
# 2
# Counter({'2019': 2})
#
# BRWD3
# 0
# Counter()
#
# BST1
# 5
# Counter({'2017': 2, '2019': 1, '2014': 1, '2015': 1})
#
# BTAF1
# 0
# Counter()
#
# BTRC
# 1
# Counter({'2021': 1})
#
# C12orf57
# 0
# Counter()
#
# C15orf62
# 0
# Counter()
#
# C4B
# 12
# Counter({'1996': 2, '1991': 1, '2012': 1, '1995': 1, '2001': 1, '2010': 1, '1997': 1, '2008': 1, '1994': 1, '2005': 1, '1992': 1})
#
# CA6
# 0
# Counter()
#
# CACNA1A
# 9
# Counter({'2019': 3, '2015': 2, '2009': 1, '2021': 1, '2007': 1, '2020': 1})
#
# CACNA1B
# 5
# Counter({'2016': 1, '2010': 1, '2019': 1, '2020': 1, '2018': 1})
#
# CACNA1C
# 88
# Counter({'2014': 13, '2020': 11, '2019': 10, '2011': 8, '2018': 8, '2016': 8, '2017': 7, '2013': 7, '2015': 7, '2021': 4, '2012': 3, '2006': 1, '2009': 1})
#
# CACNA1D
# 14
# Counter({'2016': 4, '2020': 3, '2017': 2, '2019': 2, '2018': 1, '2021': 1, '2015': 1})
#
# CACNA1E
# 4
# Counter({'2021': 2, '2020': 1, '2016': 1})
#
# CACNA1F
# 3
# Counter({'2020': 1, '2011': 1, '2007': 1})
#
# CACNA1G
# 3
# Counter({'2020': 1, '2010': 1, '2009': 1})
#
# CACNA1H
# 12
# Counter({'2018': 2, '2020': 2, '2007': 2, '2021': 1, '2016': 1, '2006': 1, '2010': 1, '2019': 1, '2008': 1})
#
# CACNA1I
# 2
# Counter({'2020': 1, '2012': 1})
#
# CACNA2D1
# 2
# Counter({'2021': 1, '2018': 1})
#
# CACNA2D3
# 2
# Counter({'2020': 1, '2021': 1})
#
# CACNB2
# 8
# Counter({'2020': 2, '2014': 2, '2015': 1, '2021': 1, '2016': 1, '2013': 1})
#
# CADM1
# 19
# Counter({'2012': 4, '2010': 2, '2007': 2, '2009': 2, '2020': 2, '2000': 1, '2021': 1, '2015': 1, '2019': 1, '2013': 1, '2008': 1, '2018': 1})
#
# CADM2
# 3
# Counter({'2016': 1, '2021': 1, '2012': 1})
#
# CADPS
# 1
# Counter({'2003': 1})
#
# CADPS2
# 18
# Counter({'2013': 4, '2021': 2, '2019': 2, '2009': 2, '2007': 1, '2011': 1, '2014': 1, '2010': 1, '2003': 1, '2017': 1, '2018': 1, '2012': 1})
#
# CAMK2A
# 7
# Counter({'2017': 2, '2019': 2, '2021': 1, '2016': 1, '2018': 1})
#
# CAMK2B
# 0
# Counter()
#
# CAMK4
# 4
# Counter({'2021': 1, '2014': 1, '2019': 1, '2020': 1})
#
# CAPN12
# 0
# Counter()
#
# CAPRIN1
# 3
# Counter({'2016': 1, '2013': 1, '2020': 1})
#
# CARD11
# 0
# Counter()
#
# CASK
# 16
# Counter({'2015': 3, '2021': 3, '2017': 2, '2020': 2, '2014': 2, '2018': 2, '2007': 1, '2016': 1})
#
# CASZ1
# 0
# Counter()
#
# CC2D1A
# 11
# Counter({'2020': 3, '2021': 3, '2017': 1, '2018': 1, '2014': 1, '2016': 1, '2019': 1})
#
# CCDC88C
# 0
# Counter()
#
# CCDC91
# 0
# Counter()
#
# CCIN
# 0
# Counter()
#
# CCNG1
# 0
# Counter()
#
# CCNK
# 1
# Counter({'2018': 1})
#
# CCSER1
# 0
# Counter()
#
# CCT4
# 0
# Counter()
#
# CD276
# 0
# Counter()
#
# CD38
# 44
# Counter({'2012': 7, '2017': 6, '2019': 6, '2020': 5, '2016': 4, '2011': 4, '2021': 3, '2018': 3, '2010': 2, '2014': 2, '2015': 1, '2013': 1})
#
# CDC42BPB
# 0
# Counter()
#
# BRINP3
# 1
# Counter({'2016': 1})
#
# CACNB1
# 3
# Counter({'2016': 1, '2020': 1, '2017': 1})
#
# CD99L2
# 1
# Counter({'2012': 1})
#
# CDH10
# 0
# Counter()
#
# CDH11
# 6
# Counter({'2021': 3, '2014': 1, '2018': 1, '2019': 1})
#
# CDH13
# 9
# Counter({'2011': 2, '2018': 2, '2015': 1, '2019': 1, '2021': 1, '2012': 1, '2010': 1})
#
# CDH22
# 0
# Counter()
#
# CDH8
# 9
# Counter({'2021': 2, '2020': 2, '2015': 2, '2013': 1, '2012': 1, '2011': 1})
#
# CDH9
# 0
# Counter()
#
# CDK13
# 2
# Counter({'2018': 1, '1993': 1})
#
# CDK19
# 1
# Counter({'2019': 1})
#
# CDK8
# 2
# Counter({'2018': 1, '2021': 1})
#
# CDKL5
# 23
# Counter({'2015': 4, '2020': 4, '2012': 3, '2016': 3, '2017': 2, '2011': 1, '2009': 1, '2019': 1, '2018': 1, '2008': 1, '2014': 1, '1993': 1})
#
# BICRA
# 1
# Counter({'2020': 1})
#
# BICDL1
# 0
# Counter()
#
# CECR2
# 2
# Counter({'2018': 1, '2006': 1})
#
# CELF4
# 2
# Counter({'2017': 1, '2019': 1})
#
# CELF6
# 3
# Counter({'2016': 1, '2018': 1, '2013': 1})
#
# CEP135
# 0
# Counter()
#
# CEP290
# 3
# Counter({'2014': 2, '2018': 1})
#
# CEP41
# 1
# Counter({'2019': 1})
#
# CGNL1
# 0
# Counter()
#
# CHAMP1
# 1
# Counter({'2021': 1})
#
# CHD1
# 1
# Counter({'2018': 1})
#
# CHD2
# 15
# Counter({'2020': 3, '2014': 3, '2018': 2, '2017': 2, '2019': 2, '2021': 2, '2016': 1})
#
# CHD3
# 2
# Counter({'2021': 2})
#
# CHD7
# 13
# Counter({'2021': 4, '2018': 3, '2015': 1, '2020': 1, '2014': 1, '2019': 1, '2013': 1, '2012': 1})
#
# CHD8
# 100
# Counter({'2020': 23, '2018': 19, '2021': 15, '2016': 9, '2015': 9, '2014': 8, '2017': 6, '2019': 5, '2012': 5, '2013': 1})
#
# CHKB
# 2
# Counter({'2020': 1, '2013': 1})
#
# CHMP1A
# 0
# Counter()
#
# CHRM3
# 1
# Counter({'2013': 1})
#
# CHRNA7
# 25
# Counter({'2016': 4, '2017': 4, '2015': 3, '2020': 2, '2019': 2, '2012': 2, '2002': 1, '2010': 1, '2009': 1, '2011': 1, '2014': 1, '2004': 1, '2021': 1, '2013': 1})
#
# CHRNB3
# 1
# Counter({'2009': 1})
#
# CIB2
# 1
# Counter({'2012': 1})
#
# CIC
# 2
# Counter({'2014': 1, '2017': 1})
#
# CLASP1
# 0
# Counter()
#
# CLCN4
# 0
# Counter()
#
# CLN8
# 0
# Counter()
#
# CLTCL1
# 2
# Counter({'2019': 1, '2012': 1})
#
# CDON
# 0
# Counter()
#
# CHM
# 1
# Counter({'2020': 1})
#
# CLIP2
# 3
# Counter({'2021': 2, '2020': 1})
#
# CMIP
# 3
# Counter({'2015': 1, '2012': 1, '2017': 1})
#
# CMPK2
# 0
# Counter()
#
# CNGB3
# 0
# Counter()
#
# CNKSR2
# 3
# Counter({'2021': 2, '2018': 1})
#
# CNOT3
# 1
# Counter({'2020': 1})
#
# CNR1
# 0
# Counter()
#
# CNTN3
# 2
# Counter({'2015': 1, '2020': 1})
#
# CNTN4
# 20
# Counter({'2013': 4, '2009': 3, '2016': 2, '2020': 2, '2018': 2, '2008': 2, '2012': 1, '2011': 1, '2017': 1, '2021': 1, '2015': 1})
#
# CNTN5
# 13
# Counter({'2013': 3, '2020': 2, '2011': 2, '2015': 2, '2018': 1, '2014': 1, '2017': 1, '2019': 1})
#
# CNTN6
# 17
# Counter({'2020': 4, '2016': 2, '2015': 2, '2017': 2, '2013': 2, '2012': 1, '2021': 1, '2018': 1, '2014': 1, '2011': 1})
#
# CNTNAP2
# 144
# Counter({'2020': 16, '2016': 14, '2021': 14, '2018': 14, '2019': 14, '2017': 13, '2015': 12, '2011': 9, '2008': 8, '2010': 8, '2012': 7, '2014': 6, '2013': 5, '2009': 4})
#
# CNTNAP3
# 1
# Counter({'2019': 1})
#
# CNTNAP4
# 3
# Counter({'2021': 1, '2017': 1, '2018': 1})
#
# CNTNAP5
# 4
# Counter({'2020': 2, '2010': 1, '2021': 1})
#
# COL28A1
# 0
# Counter()
#
# CPT2
# 0
# Counter()
#
# CPZ
# 2
# Counter({'1985': 1, '2012': 1})
#
# CREBBP
# 14
# Counter({'2015': 4, '2021': 2, '2014': 2, '2016': 1, '2009': 1, '2008': 1, '2005': 1, '2013': 1, '2020': 1})
#
# CSDE1
# 5
# Counter({'2021': 3, '2014': 1, '2019': 1})
#
# CSMD1
# 8
# Counter({'2014': 2, '2021': 2, '2017': 2, '2016': 1, '2009': 1})
#
# CSNK1E
# 0
# Counter()
#
# CTCF
# 5
# Counter({'2019': 2, '2015': 1, '2020': 1, '2008': 1})
#
# CTNNA2
# 0
# Counter()
#
# CTNNA3
# 0
# Counter()
#
# CTNNB1
# 10
# Counter({'2014': 3, '2017': 2, '2015': 2, '2020': 1, '2016': 1, '2021': 1})
#
# CTNND2
# 0
# Counter()
#
# CTTNBP2
# 3
# Counter({'2020': 2, '2001': 1})
#
# CUL3
# 12
# Counter({'2020': 4, '2021': 4, '2017': 1, '2015': 1, '2019': 1, '2016': 1})
#
# CNOT1
# 0
# Counter()
#
# CORO1A
# 0
# Counter()
#
# CSNK1G1
# 1
# Counter({'2020': 1})
#
# CSNK2A1
# 1
# Counter({'2020': 1})
#
# CSNK2B
# 0
# Counter()
#
# CUL7
# 1
# Counter({'2015': 1})
#
# CUX1
# 8
# Counter({'2016': 3, '2020': 1, '2021': 1, '2012': 1, '2018': 1, '2019': 1})
#
# CUX2
# 2
# Counter({'2018': 1, '2019': 1})
#
# CX3CR1
# 0
# Counter()
#
# CYFIP1
# 35
# Counter({'2014': 7, '2019': 7, '2020': 3, '2015': 3, '2021': 3, '2012': 2, '2007': 2, '2013': 2, '2018': 2, '2006': 1, '2010': 1, '2016': 1, '2017': 1})
#
# CYLC2
# 0
# Counter()
#
# CYP27A1
# 1
# Counter({'2018': 1})
#
# DAGLA
# 4
# Counter({'2021': 1, '2018': 1, '2017': 1, '2013': 1})
#
# DAPP1
# 2
# Counter({'2020': 1, '2012': 1})
#
# DDC
# 8
# Counter({'2016': 1, '2000': 1, '2002': 1, '2021': 1, '2020': 1, '2013': 1, '2019': 1, '2014': 1})
#
# DDX3X
# 0
# Counter()
#
# DDX53
# 0
# Counter()
#
# DEAF1
# 5
# Counter({'2019': 1, '2015': 1, '2018': 1, '2020': 1, '2021': 1})
#
# DENR
# 1
# Counter({'2021': 1})
#
# DEPDC5
# 2
# Counter({'1993': 1, '2017': 1})
#
# DHCR7
# 6
# Counter({'2016': 3, '2009': 1, '2017': 1, '2003': 1})
#
# DHX30
# 0
# Counter()
#
# DIP2A
# 0
# Counter()
#
# DIP2C
# 0
# Counter()
#
# DISC1
# 23
# Counter({'2016': 5, '2010': 2, '2012': 2, '2014': 2, '2009': 2, '2020': 2, '2017': 2, '2018': 2, '2008': 2, '2011': 1, '2019': 1})
#
# DIXDC1
# 2
# Counter({'2016': 1, '2021': 1})
#
# DIPK2A
# 2
# Counter({'2011': 1, '2013': 1})
#
# DLG1
# 10
# Counter({'2019': 3, '2021': 2, '2016': 2, '2010': 1, '2020': 1, '2014': 1})
#
# DLG2
# 4
# Counter({'2020': 1, '2019': 1, '2016': 1, '2014': 1})
#
# DLG4
# 31
# Counter({'2014': 6, '2015': 4, '2017': 4, '2019': 4, '2016': 3, '2018': 3, '2021': 2, '2011': 1, '2013': 1, '2005': 1, '2020': 1, '2012': 1})
#
# DLGAP1
# 6
# Counter({'2016': 2, '2021': 1, '2011': 1, '2018': 1, '2019': 1})
#
# DLGAP2
# 1
# Counter({'2013': 1})
#
# DLGAP3
# 1
# Counter({'2016': 1})
#
# DLL1
# 2
# Counter({'2016': 1, '2019': 1})
#
# DLX3
# 2
# Counter({'2016': 1, '2018': 1})
#
# DLX6
# 4
# Counter({'2010': 2, '2003': 1, '2017': 1})
#
# DMD
# 0
# Counter()
#
# DMPK
# 4
# Counter({'2020': 2, '2008': 1, '2016': 1})
#
# CPEB4
# 1
# Counter({'2018': 1})
#
# CYP11B1
# 2
# Counter({'2009': 1, '2016': 1})
#
# DDHD2
# 2
# Counter({'2020': 1, '2021': 1})
#
# DDX23
# 1
# Counter({'2021': 1})
#
# DLX2
# 4
# Counter({'2005': 1, '2004': 1, '2009': 1, '2003': 1})
#
# DMWD
# 0
# Counter()
#
# DMXL2
# 1
# Counter({'2019': 1})
#
# DNAH10
# 0
# Counter()
#
# DNAH17
# 2
# Counter({'2020': 2})
#
# DNAH3
# 0
# Counter()
#
# DNER
# 3
# Counter({'2012': 1, '2020': 1, '2015': 1})
#
# DNMT3A
# 0
# Counter()
#
# DCC
# 8
# Counter({'2020': 6, '2001': 1, '2018': 1})
#
# DOCK1
# 4
# Counter({'2020': 2, '2017': 1, '2021': 1})
#
# DOCK4
# 11
# Counter({'2021': 3, '2014': 2, '2010': 2, '2013': 1, '2018': 1, '2012': 1, '2019': 1})
#
# DOCK8
# 7
# Counter({'2019': 2, '2020': 1, '2021': 1, '2007': 1, '2017': 1, '2016': 1})
#
# DOLK
# 2
# Counter({'2013': 1, '2019': 1})
#
# DPP10
# 6
# Counter({'2020': 2, '2013': 1, '2017': 1, '2014': 1, '2008': 1})
#
# DPP3
# 0
# Counter()
#
# DPP4
# 11
# Counter({'2015': 2, '2003': 2, '2002': 1, '2014': 1, '2012': 1, '2019': 1, '2017': 1, '2021': 1, '2004': 1})
#
# DPP6
# 10
# Counter({'2014': 2, '2021': 1, '2019': 1, '2020': 1, '2010': 1, '2016': 1, '2017': 1, '2018': 1, '2008': 1})
#
# DPYD
# 10
# Counter({'2011': 2, '2015': 2, '2016': 1, '2008': 1, '2010': 1, '2000': 1, '2021': 1, '2012': 1})
#
# DPYSL2
# 3
# Counter({'2009': 2, '2016': 1})
#
# DPYSL3
# 1
# Counter({'2017': 1})
#
# DRD1
# 13
# Counter({'2016': 2, '2014': 2, '2019': 2, '2020': 2, '2017': 1, '2021': 1, '2008': 1, '2018': 1, '2015': 1})
#
# DRD2
# 33
# Counter({'2021': 4, '2018': 4, '2019': 4, '2017': 4, '2016': 3, '2014': 3, '2010': 2, '2020': 2, '2013': 2, '1991': 1, '2007': 1, '2005': 1, '2015': 1, '1999': 1})
#
# DRD3
# 16
# Counter({'2013': 2, '2010': 2, '2015': 2, '2020': 2, '2021': 1, '2009': 1, '2014': 1, '2017': 1, '2019': 1, '1994': 1, '2012': 1, '2016': 1})
#
# DSCAM
# 7
# Counter({'2021': 3, '2016': 2, '2017': 1, '2020': 1})
#
# DST
# 9
# Counter({'1987': 3, '2021': 2, '1993': 1, '1984': 1, '2019': 1, '2008': 1})
#
# DUSP15
# 2
# Counter({'2017': 1, '2021': 1})
#
# DVL3
# 0
# Counter()
#
# DYDC1
# 0
# Counter()
#
# DYDC2
# 0
# Counter()
#
# DYNC1H1
# 2
# Counter({'2021': 2})
#
# DYRK1A
# 0
# Counter()
#
# EBF3
# 2
# Counter({'2017': 1, '2020': 1})
#
# EEF1A2
# 5
# Counter({'2020': 2, '2015': 1, '2016': 1, '2019': 1})
#
# EFR3A
# 0
# Counter()
#
# EGR3
# 3
# Counter({'2009': 1, '2020': 1, '2021': 1})
#
# EHMT1
# 26
# Counter({'2020': 5, '2016': 4, '2017': 3, '2018': 2, '2012': 2, '2015': 2, '2013': 2, '2014': 2, '2021': 1, '2019': 1, '2007': 1, '2010': 1})
#
# EIF3G
# 0
# Counter()
#
# EIF4E
# 24
# Counter({'2020': 4, '2015': 4, '2021': 3, '2019': 3, '2013': 3, '2017': 2, '2018': 2, '2014': 2, '2009': 1})
#
# ELAVL2
# 1
# Counter({'2016': 1})
#
# ELAVL3
# 0
# Counter()
#
# ELP4
# 3
# Counter({'2015': 1, '2016': 1, '2021': 1})
#
# EN2
# 53
# Counter({'2015': 7, '2014': 6, '2016': 4, '2018': 4, '2012': 4, '2013': 3, '2017': 3, '2009': 3, '2008': 3, '2019': 2, '2020': 2, '2010': 2, '2005': 2, '2011': 1, '2004': 1, '2006': 1, '1995': 1, '2007': 1, '2003': 1, '2021': 1, '1999': 1})
#
# EP300
# 3
# Counter({'2020': 1, '2016': 1, '2008': 1})
#
# EP400
# 0
# Counter()
#
# EMSY
# 0
# Counter()
#
# EPC2
# 0
# Counter()
#
# EPHB2
# 1
# Counter({'2021': 1})
#
# EPPK1
# 0
# Counter()
#
# ERMN
# 2
# Counter({'2021': 1, '2016': 1})
#
# ESR2
# 0
# Counter()
#
# ESRRB
# 0
# Counter()
#
# ETFB
# 0
# Counter()
#
# EXOC3
# 0
# Counter()
#
# EXOC5
# 0
# Counter()
#
# EXOC6
# 1
# Counter({'2021': 1})
#
# EXOC6B
# 0
# Counter()
#
# EXT1
# 3
# Counter({'2017': 1, '2012': 1, '2002': 1})
#
# ERBIN
# 1
# Counter({'2020': 1})
#
# FABP5
# 0
# Counter()
#
# FAM47A
# 0
# Counter()
#
# FAM98C
# 0
# Counter()
#
# FAN1
# 3
# Counter({'2014': 1, '2020': 1, '2016': 1})
#
# FAT1
# 4
# Counter({'2021': 2, '2014': 2})
#
# FBN1
# 1
# Counter({'2020': 1})
#
# FBXO11
# 3
# Counter({'2020': 2, '2019': 1})
#
# FBXO40
# 1
# Counter({'2009': 1})
#
# FCRL6
# 0
# Counter()
#
# FEZF2
# 3
# Counter({'2013': 1, '2020': 1, '2014': 1})
#
# FGA
# 2
# Counter({'2018': 1, '2013': 1})
#
# FHIT
# 5
# Counter({'2013': 2, '2020': 1, '2021': 1, '2016': 1})
#
# FMR1
# 390
# Counter({'2020': 45, '2021': 38, '2017': 37, '2019': 35, '2014': 34, '2015': 34, '2018': 33, '2016': 31, '2011': 17, '2012': 16, '2013': 14, '2010': 10, '2007': 9, '2006': 6, '2008': 5, '2009': 5, '2004': 4, '2005': 3, '1998': 2, '1996': 2, '2002': 2, '2001': 2, '1997': 2, '2003': 2, '1994': 1, '1993': 1})
#
# FOXG1
# 7
# Counter({'2020': 2, '2021': 1, '2015': 1, '2014': 1, '2016': 1, '2017': 1})
#
# FOXP1
# 37
# Counter({'2017': 8, '2019': 4, '2013': 4, '2021': 4, '2012': 4, '2015': 3, '2020': 3, '2018': 3, '2011': 2, '2016': 1, '2010': 1})
#
# FOXP2
# 56
# Counter({'2012': 7, '2017': 4, '2016': 4, '2021': 4, '2019': 4, '2014': 3, '2018': 3, '2020': 3, '2002': 3, '2013': 3, '2010': 3, '2006': 3, '2011': 2, '2005': 2, '2008': 2, '2004': 2, '1993': 1, '2015': 1, '2007': 1, '2003': 1})
#
# FRK
# 0
# Counter()
#
# FRMPD4
# 0
# Counter()
#
# GABBR2
# 5
# Counter({'2012': 2, '2009': 1, '2021': 1, '2020': 1})
#
# GABRA3
# 0
# Counter()
#
# GABRA4
# 1
# Counter({'2018': 1})
#
# GABRB3
# 5
# Counter({'2011': 2, '2007': 1, '2004': 1, '2009': 1})
#
# GABRG3
# 16
# Counter({'2018': 2, '2007': 2, '2001': 2, '2004': 1, '2019': 1, '1999': 1, '2021': 1, '2010': 1, '2017': 1, '2006': 1, '2012': 1, '2005': 1, '2016': 1})
#
# GALNT13
# 0
# Counter()
#
# GALNT14
# 0
# Counter()
#
# GALNT8
# 0
# Counter()
#
# GATM
# 0
# Counter()
#
# EIF4G1
# 3
# Counter({'2020': 2, '2011': 1})
#
# ELOVL2
# 2
# Counter({'2018': 1, '2015': 1})
#
# ELP2
# 1
# Counter({'2021': 1})
#
# ENPP1
# 1
# Counter({'2020': 1})
#
# ERG
# 10
# Counter({'2019': 2, '1989': 2, '2020': 2, '2016': 1, '2014': 1, '2021': 1, '1990': 1})
#
# FABP4
# 5
# Counter({'2021': 3, '2015': 1, '2020': 1})
#
# FBRSL1
# 0
# Counter()
#
# FBXO33
# 0
# Counter()
#
# FGF13
# 1
# Counter({'2017': 1})
#
# FGF14
# 2
# Counter({'2020': 1, '2019': 1})
#
# FRG1
# 0
# Counter()
#
# FXN
# 1
# Counter({'2020': 1})
#
# GABRB2
# 4
# Counter({'2022': 1, '2017': 1, '2018': 1, '2005': 1})
#
# GALNT2
# 0
# Counter()
#
# GAS2
# 0
# Counter()
#
# GDA
# 3
# Counter({'2013': 1, '2021': 1, '2020': 1})
#
# GGNBP2
# 1
# Counter({'2018': 1})
#
# GIGYF1
# 0
# Counter()
#
# GIGYF2
# 4
# Counter({'2014': 1, '2020': 1, '2016': 1, '2018': 1})
#
# GLIS1
# 1
# Counter({'2015': 1})
#
# GLO1
# 11
# Counter({'2008': 2, '2014': 1, '2015': 1, '2016': 1, '2019': 1, '2020': 1, '1989': 1, '2011': 1, '2004': 1, '2007': 1})
#
# GLRA2
# 5
# Counter({'2017': 2, '2016': 1, '2019': 1, '2018': 1})
#
# GNAS
# 1
# Counter({'2000': 1})
#
# GNB1L
# 0
# Counter()
#
# GPC4
# 2
# Counter({'2018': 1, '2016': 1})
#
# GPC6
# 2
# Counter({'2016': 1, '2015': 1})
#
# GPD2
# 3
# Counter({'2019': 1, '2018': 1, '2013': 1})
#
# GPHN
# 23
# Counter({'2016': 5, '2019': 5, '2014': 3, '2015': 2, '2021': 2, '2011': 1, '2020': 1, '2017': 1, '2012': 1, '2018': 1, '2013': 1})
#
# GPR37
# 2
# Counter({'2015': 1, '2012': 1})
#
# GPR85
# 2
# Counter({'2018': 1, '2015': 1})
#
# GPX1
# 4
# Counter({'2015': 1, '2020': 1, '2016': 1, '2010': 1})
#
# GRIA1
# 5
# Counter({'2018': 2, '2019': 1, '2020': 1, '2017': 1})
#
# GRIA2
# 4
# Counter({'2021': 3, '2019': 1})
#
# GRID1
# 2
# Counter({'2012': 1, '2020': 1})
#
# GRID2
# 7
# Counter({'2020': 2, '2012': 1, '2018': 1, '2016': 1, '2017': 1, '2014': 1})
#
# GRID2IP
# 0
# Counter()
#
# GRIK2
# 10
# Counter({'2012': 2, '2004': 2, '2007': 2, '2014': 1, '2010': 1, '2002': 1, '2019': 1})
#
# GRIK3
# 2
# Counter({'2004': 1, '2019': 1})
#
# GRIK4
# 5
# Counter({'2012': 2, '2015': 1, '2002': 1, '2018': 1})
#
# GRIK5
# 1
# Counter({'2019': 1})
#
# GRIN1
# 16
# Counter({'2021': 3, '2015': 2, '2016': 2, '2017': 2, '2014': 2, '2011': 1, '2008': 1, '2019': 1, '2020': 1, '2018': 1})
#
# GRIN2A
# 13
# Counter({'2018': 5, '2021': 2, '2020': 2, '2011': 1, '2012': 1, '2005': 1, '2022': 1})
#
# FGFR1
# 3
# Counter({'2010': 1, '2009': 1, '2018': 1})
#
# GALNT10
# 0
# Counter()
#
# GFAP
# 68
# Counter({'2019': 10, '2015': 8, '2017': 7, '2018': 5, '2012': 4, '2021': 4, '2008': 3, '2005': 3, '2020': 3, '2013': 2, '2007': 2, '2014': 2, '2016': 2, '1992': 2, '2002': 1, '2004': 1, '2011': 1, '1997': 1, '2009': 1, '1993': 1, '1985': 1, '1990': 1, '1989': 1, '1988': 1, '2010': 1})
#
# GNAI1
# 0
# Counter()
#
# GRIN2B
# 33
# Counter({'2016': 6, '2020': 5, '2011': 4, '2021': 4, '2015': 3, '2012': 3, '2017': 2, '2019': 2, '2014': 1, '2013': 1, '2018': 1, '1993': 1})
#
# GRIP1
# 5
# Counter({'2014': 1, '2011': 1, '2017': 1, '2015': 1, '2019': 1})
#
# GRM5
# 20
# Counter({'2011': 3, '2015': 3, '2016': 3, '2019': 2, '2021': 2, '2018': 2, '2010': 2, '2017': 1, '2012': 1, '2014': 1})
#
# GRM7
# 12
# Counter({'2018': 2, '2019': 2, '2021': 2, '2020': 1, '2012': 1, '2016': 1, '2013': 1, '2015': 1, '2017': 1})
#
# GTF2I
# 10
# Counter({'2020': 2, '2021': 2, '2012': 1, '2017': 1, '2015': 1, '2018': 1, '2007': 1, '2019': 1})
#
# GUCY1A2
# 0
# Counter()
#
# HCFC1
# 1
# Counter({'2019': 1})
#
# HCN1
# 1
# Counter({'2016': 1})
#
# HDAC4
# 10
# Counter({'2014': 4, '2017': 1, '2019': 1, '2016': 1, '2012': 1, '2010': 1, '1993': 1})
#
# HDAC8
# 5
# Counter({'2019': 2, '2015': 1, '2017': 1, '2021': 1})
#
# HDLBP
# 1
# Counter({'2009': 1})
#
# HECTD4
# 0
# Counter()
#
# HECW2
# 0
# Counter()
#
# HEPACAM
# 2
# Counter({'2011': 1, '2014': 1})
#
# H2BC11
# 0
# Counter()
#
# HERC2
# 4
# Counter({'2019': 1, '2012': 1, '2000': 1, '2018': 1})
#
# HIVEP2
# 2
# Counter({'2020': 1, '2019': 1})
#
# HIVEP3
# 0
# Counter()
#
# HLA-DPB1
# 0
# Counter()
#
# HNRNPH2
# 2
# Counter({'2021': 1, '2016': 1})
#
# HNRNPU
# 3
# Counter({'2014': 1, '2018': 1, '2017': 1})
#
# HOMER1
# 0
# Counter()
#
# HOXA1
# 25
# Counter({'2002': 6, '2007': 3, '2004': 3, '2003': 2, '2011': 2, '2000': 2, '2005': 2, '2001': 1, '2012': 1, '2010': 1, '2008': 1, '2009': 1})
#
# HRAS
# 8
# Counter({'2017': 1, '2002': 1, '1995': 1, '2020': 1, '1993': 1, '1996': 1, '1994': 1, '2015': 1})
#
# HTR1B
# 0
# Counter()
#
# HTR3A
# 0
# Counter()
#
# HTR3C
# 0
# Counter()
#
# HUWE1
# 7
# Counter({'2020': 1, '2019': 1, '2018': 1, '2014': 1, '2017': 1, '2012': 1, '2021': 1})
#
# HYDIN
# 3
# Counter({'2018': 1, '2020': 1, '2013': 1})
#
# ICA1
# 2
# Counter({'2011': 1, '2010': 1})
#
# IL1R2
# 0
# Counter()
#
# IL1RAPL1
# 19
# Counter({'2011': 4, '2015': 3, '2008': 2, '2014': 2, '2019': 2, '2013': 2, '2010': 2, '2017': 1, '2018': 1})
#
# IL1RAPL2
# 2
# Counter({'2011': 1, '2008': 1})
#
# ILF2
# 0
# Counter()
#
# IMMP2L
# 0
# Counter()
#
# INPP1
# 1
# Counter({'2003': 1})
#
# INTS1
# 0
# Counter()
#
# INTS6
# 0
# Counter()
#
# IQGAP3
# 0
# Counter()
#
# IQSEC2
# 8
# Counter({'2021': 4, '2019': 2, '2015': 1, '2020': 1})
#
# IRF2BPL
# 0
# Counter()
#
# ITGB3
# 0
# Counter()
#
# ITPR1
# 5
# Counter({'2020': 2, '2014': 1, '2013': 1, '2016': 1})
#
# ITSN1
# 3
# Counter({'2021': 3})
#
# GSTM1
# 17
# Counter({'2021': 3, '2020': 3, '2019': 2, '2014': 2, '2016': 2, '2010': 2, '2015': 1, '2006': 1, '2017': 1})
#
# HLA-A
# 6
# Counter({'2015': 1, '2020': 1, '2011': 1, '2018': 1, '2006': 1, '1980': 1})
#
# HNRNPD
# 0
# Counter()
#
# HNRNPF
# 0
# Counter()
#
# HNRNPK
# 1
# Counter({'2021': 1})
#
# HNRNPR
# 0
# Counter()
#
# HNRNPUL2
# 0
# Counter()
#
# IGF1
# 49
# Counter({'2020': 6, '2021': 6, '2017': 6, '2015': 5, '2019': 5, '2016': 5, '2014': 4, '2013': 3, '2009': 2, '2006': 1, '2012': 1, '2003': 1, '2011': 1, '2007': 1, '2018': 1, '2010': 1})
#
# JARID2
# 5
# Counter({'2018': 1, '2016': 1, '2011': 1, '2017': 1, '2012': 1})
#
# JMJD1C
# 6
# Counter({'2021': 2, '2020': 1, '2016': 1, '2007': 1, '2019': 1})
#
# KANK1
# 7
# Counter({'2021': 2, '2019': 1, '2020': 1, '2013': 1, '2007': 1, '2017': 1})
#
# KANSL1
# 1
# Counter({'2016': 1})
#
# KAT2B
# 0
# Counter()
#
# KAT6A
# 0
# Counter()
#
# HLA-B
# 6
# Counter({'2015': 2, '2020': 1, '2011': 1, '2006': 1, '1980': 1})
#
# HLA-DRB1
# 15
# Counter({'2013': 2, '2006': 2, '2018': 2, '2011': 1, '2015': 1, '2016': 1, '2012': 1, '2020': 1, '2002': 1, '1996': 1, '2009': 1, '2001': 1})
#
# HLA-G
# 7
# Counter({'2020': 2, '2018': 2, '2015': 1, '2019': 1, '2016': 1})
#
# HMGN1
# 0
# Counter()
#
# HS3ST5
# 0
# Counter()
#
# HSD11B1
# 0
# Counter()
#
# KATNAL1
# 0
# Counter()
#
# KATNAL2
# 3
# Counter({'2012': 1, '2016': 1, '2021': 1})
#
# KCNB1
# 8
# Counter({'2020': 3, '2021': 3, '2018': 1, '2019': 1})
#
# KCNC1
# 1
# Counter({'2016': 1})
#
# KCND2
# 5
# Counter({'2015': 1, '2021': 1, '2018': 1, '2012': 1, '2014': 1})
#
# KCND3
# 3
# Counter({'2021': 1, '2016': 1, '2013': 1})
#
# KCNJ10
# 5
# Counter({'2015': 1, '2021': 1, '2020': 1, '2018': 1, '2011': 1})
#
# KCNJ15
# 0
# Counter()
#
# KCNK7
# 0
# Counter()
#
# KCNMA1
# 7
# Counter({'2021': 2, '2020': 2, '2015': 1, '2006': 1, '2007': 1})
#
# KCNQ2
# 9
# Counter({'2021': 4, '2019': 2, '2013': 2, '2018': 1})
#
# KCNQ3
# 4
# Counter({'2019': 2, '2015': 1, '2021': 1})
#
# KCNS3
# 1
# Counter({'2016': 1})
#
# KCTD13
# 6
# Counter({'2017': 2, '2020': 1, '2021': 1, '2015': 1, '2019': 1})
#
# KDM1B
# 0
# Counter()
#
# KDM3B
# 0
# Counter()
#
# KDM4B
# 0
# Counter()
#
# KDM4C
# 3
# Counter({'2007': 1, '2010': 1, '2020': 1})
#
# KDM5B
# 0
# Counter()
#
# KDM5C
# 9
# Counter({'2019': 3, '2021': 2, '2014': 1, '2015': 1, '2010': 1, '2016': 1})
#
# KDM6A
# 1
# Counter({'2015': 1})
#
# KDM6B
# 0
# Counter()
#
# KHDRBS2
# 0
# Counter()
#
# KIAA1586
# 0
# Counter()
#
# KIF13B
# 0
# Counter()
#
# KIF14
# 1
# Counter({'2015': 1})
#
# KAT6B
# 0
# Counter()
#
# KDM5A
# 5
# Counter({'2014': 2, '2020': 1, '2008': 1, '2019': 1})
#
# KIAA0232
# 0
# Counter()
#
# KIF1A
# 8
# Counter({'2020': 3, '2018': 1, '2021': 1, '2017': 1, '2009': 1, '2019': 1})
#
# KIF5C
# 0
# Counter()
#
# KIRREL3
# 0
# Counter()
#
# KLF16
# 2
# Counter({'2007': 1, '2017': 1})
#
# KMT2A
# 0
# Counter()
#
# KMT2C
# 0
# Counter()
#
# KMT2E
# 0
# Counter()
#
# KPTN
# 1
# Counter({'2020': 1})
#
# KRR1
# 0
# Counter()
#
# KRT26
# 0
# Counter()
#
# LAMA1
# 2
# Counter({'1997': 1, '2013': 1})
#
# LAMB1
# 3
# Counter({'2004': 1, '2005': 1, '2015': 1})
#
# LEO1
# 1
# Counter({'2018': 1})
#
# LEP
# 38
# Counter({'2014': 7, '2018': 6, '2021': 5, '2016': 4, '2017': 3, '2019': 3, '2004': 2, '2020': 2, '2015': 2, '2010': 1, '2008': 1, '2011': 1, '2012': 1})
#
# LILRB2
# 0
# Counter()
#
# LIN7B
# 2
# Counter({'2014': 1, '2015': 1})
#
# KMT5B
# 4
# Counter({'2021': 2, '2017': 1, '2019': 1})
#
# LNPK
# 0
# Counter()
#
# LRBA
# 0
# Counter()
#
# LRFN2
# 1
# Counter({'2017': 1})
#
# LRFN5
# 2
# Counter({'2019': 1, '2011': 1})
#
# LRP1
# 2
# Counter({'2018': 1, '2019': 1})
#
# LRP2
# 1
# Counter({'2012': 1})
#
# LRRC1
# 0
# Counter()
#
# LRRC4
# 4
# Counter({'2019': 1, '2021': 1, '2020': 1, '2018': 1})
#
# LZTR1
# 1
# Counter({'2015': 1})
#
# MACROD2
# 14
# Counter({'2017': 3, '2011': 2, '2013': 2, '2019': 2, '2014': 1, '2010': 1, '2020': 1, '2015': 1, '2012': 1})
#
# MAGEL2
# 23
# Counter({'2020': 7, '2018': 3, '2017': 2, '2015': 2, '2021': 2, '2019': 2, '2001': 1, '2013': 1, '2008': 1, '2016': 1, '2012': 1})
#
# MAOA
# 28
# Counter({'2014': 4, '2017': 3, '2016': 3, '2013': 3, '2018': 2, '2008': 2, '2009': 2, '2011': 2, '2012': 1, '2015': 1, '1999': 1, '2021': 1, '2003': 1, '2020': 1, '2002': 1})
#
# MAOB
# 13
# Counter({'2009': 2, '2013': 2, '2018': 2, '2011': 1, '2017': 1, '2014': 1, '1999': 1, '2021': 1, '2019': 1, '2016': 1})
#
# MAPK3
# 17
# Counter({'2017': 3, '2021': 2, '2011': 2, '2018': 2, '2020': 1, '2016': 1, '2015': 1, '2014': 1, '2010': 1, '2013': 1, '2012': 1, '2019': 1})
#
# MARK1
# 2
# Counter({'2016': 1, '2008': 1})
#
# MBD1
# 5
# Counter({'2010': 2, '2009': 1, '2005': 1, '2008': 1})
#
# MBD3
# 2
# Counter({'2010': 1, '2005': 1})
#
# MBD4
# 3
# Counter({'2010': 1, '2005': 1, '2009': 1})
#
# MBD5
# 21
# Counter({'2017': 4, '2021': 3, '2014': 2, '2020': 2, '2015': 2, '2018': 2, '2016': 2, '2012': 2, '2013': 1, '2011': 1})
#
# MBD6
# 1
# Counter({'2012': 1})
#
# MBOAT7
# 2
# Counter({'2019': 1, '2016': 1})
#
# MCM4
# 0
# Counter()
#
# MCM6
# 1
# Counter({'2018': 1})
#
# MCPH1
# 5
# Counter({'2009': 3, '2011': 2})
#
# MDGA2
# 4
# Counter({'2013': 1, '2009': 1, '2012': 1, '2021': 1})
#
# MECP2
# 261
# Counter({'2016': 29, '2011': 21, '2014': 18, '2019': 18, '2017': 17, '2020': 16, '2015': 14, '2012': 14, '2009': 13, '2018': 13, '2010': 13, '2013': 12, '2021': 12, '2008': 12, '2007': 11, '2005': 8, '2003': 5, '2004': 5, '2006': 4, '2000': 2, '2002': 2, '1993': 1, '2001': 1})
#
# KNG1
# 2
# Counter({'2014': 1, '2015': 1})
#
# LAS1L
# 1
# Counter({'2020': 1})
#
# LDB1
# 0
# Counter()
#
# LDLR
# 9
# Counter({'2019': 5, '2016': 2, '2021': 1, '2012': 1})
#
# LMX1B
# 3
# Counter({'2020': 1, '2011': 1, '2019': 1})
#
# LRRC4C
# 3
# Counter({'2013': 1, '2017': 1, '2019': 1})
#
# LZTS2
# 0
# Counter()
#
# MED12L
# 1
# Counter({'2019': 1})
#
# MED13
# 3
# Counter({'2018': 1, '2019': 1, '2021': 1})
#
# MED13L
# 5
# Counter({'2019': 2, '2015': 1, '2014': 1, '2018': 1})
#
# MEF2C
# 16
# Counter({'2016': 3, '2021': 2, '2018': 2, '2015': 2, '2017': 2, '2019': 2, '2020': 1, '2010': 1, '2009': 1})
#
# KIZ
# 0
# Counter()
#
# MAPT
# 31
# Counter({'2021': 8, '2020': 7, '2019': 4, '2016': 4, '2012': 2, '2017': 1, '1991': 1, '2011': 1, '2010': 1, '2014': 1, '2018': 1})
#
# MAPT-AS1
# 0
# Counter()
#
# MEGF10
# 1
# Counter({'2017': 1})
#
# MEGF11
# 0
# Counter()
#
# MEIS2
# 4
# Counter({'2017': 1, '2018': 1, '2015': 1, '2020': 1})
#
# MEMO1
# 1
# Counter({'2019': 1})
#
# MET
# 0
# Counter()
#
# MFRP
# 0
# Counter()
#
# MIB1
# 1
# Counter({'2009': 1})
#
# MKX
# 0
# Counter()
#
# METTL26
# 0
# Counter()
#
# MIR137
# 9
# Counter({'2014': 2, '2016': 2, '2015': 1, '2021': 1, '2018': 1, '2011': 1, '2020': 1})
#
# MAP1A
# 3
# Counter({'2021': 1, '2011': 1, '2019': 1})
#
# MLANA
# 1
# Counter({'2019': 1})
#
# MSANTD2
# 1
# Counter({'2017': 1})
#
# MSR1
# 0
# Counter()
#
# MTF1
# 3
# Counter({'2011': 1, '2004': 1, '2014': 1})
#
# MTHFR
# 0
# Counter()
#
# MTOR
# 218
# Counter({'2021': 35, '2020': 32, '2019': 30, '2015': 27, '2016': 19, '2017': 18, '2018': 15, '2013': 12, '2014': 10, '2012': 9, '2009': 4, '2011': 4, '2010': 1, '1993': 1, '2006': 1})
#
# MUC12
# 0
# Counter()
#
# MUC4
# 1
# Counter({'2011': 1})
#
# MYH10
# 2
# Counter({'2020': 1, '2016': 1})
#
# MRTFB
# 2
# Counter({'2018': 1, '2021': 1})
#
# MYH4
# 0
# Counter()
#
# MYO16
# 3
# Counter({'2015': 1, '2013': 1, '2019': 1})
#
# MYO1E
# 1
# Counter({'2016': 1})
#
# MYO5A
# 1
# Counter({'2020': 1})
#
# MYO5C
# 0
# Counter()
#
# MYO9B
# 1
# Counter({'2018': 1})
#
# MYT1L
# 6
# Counter({'2018': 1, '2021': 1, '2012': 1, '2013': 1, '2020': 1, '2016': 1})
#
# NAA15
# 0
# Counter()
#
# NAALADL2
# 1
# Counter({'2015': 1})
#
# NACC1
# 0
# Counter()
#
# NAV2
# 0
# Counter()
#
# NBEA
# 20
# Counter({'2015': 3, '2018': 2, '2013': 2, '2020': 2, '2021': 2, '2006': 1, '2016': 1, '2010': 1, '2014': 1, '2003': 1, '2002': 1, '2009': 1, '2019': 1, '2011': 1})
#
# NCKAP1
# 2
# Counter({'2016': 1, '2020': 1})
#
# NCKAP5
# 0
# Counter()
#
# NCOR1
# 2
# Counter({'2016': 1, '2018': 1})
#
# NEGR1
# 1
# Counter({'2018': 1})
#
# NEO1
# 2
# Counter({'2020': 1, '2016': 1})
#
# NEXMIF
# 6
# Counter({'2015': 2, '2020': 2, '2018': 1, '2021': 1})
#
# NF1
# 0
# Counter()
#
# NFE2L3
# 0
# Counter()
#
# NFIA
# 5
# Counter({'2015': 1, '2020': 1, '2013': 1, '2018': 1, '2021': 1})
#
# NFIB
# 3
# Counter({'2020': 1, '2018': 1, '2012': 1})
#
# NFIX
# 0
# Counter()
#
# NINL
# 0
# Counter()
#
# NIPA1
# 7
# Counter({'2006': 1, '2017': 1, '2020': 1, '2015': 1, '2021': 1, '2010': 1, '2013': 1})
#
# NIPA2
# 6
# Counter({'2006': 1, '2017': 1, '2020': 1, '2015': 1, '2021': 1, '2013': 1})
#
# NIPBL
# 0
# Counter()
#
# NLGN1
# 49
# Counter({'2020': 7, '2021': 7, '2013': 7, '2012': 4, '2005': 3, '2008': 3, '2019': 3, '2016': 2, '2015': 2, '2014': 2, '2009': 2, '2010': 1, '2011': 1, '2004': 1, '2003': 1, '2018': 1, '2017': 1, '2007': 1})
#
# MNT
# 2
# Counter({'2019': 1, '2015': 1})
#
# MSL3
# 1
# Counter({'2021': 1})
#
# MSNP1AS
# 7
# Counter({'2016': 3, '2012': 1, '2020': 1, '2021': 1, '2019': 1})
#
# MSX2
# 3
# Counter({'2002': 1, '2020': 1, '2019': 1})
#
# MYH9
# 1
# Counter({'2012': 1})
#
# MYLK
# 1
# Counter({'2011': 1})
#
# MYOCD
# 2
# Counter({'2016': 1, '2021': 1})
#
# NCAPH2
# 1
# Counter({'2010': 1})
#
# NCOA1
# 0
# Counter()
#
# NDUFA5
# 0
# Counter()
#
# NLGN2
# 18
# Counter({'2013': 4, '2020': 3, '2019': 2, '2017': 2, '2005': 2, '2021': 1, '2011': 1, '2014': 1, '2012': 1, '2016': 1})
#
# NLGN3
# 128
# Counter({'2020': 12, '2018': 12, '2017': 11, '2021': 11, '2014': 10, '2012': 10, '2009': 8, '2011': 6, '2015': 6, '2008': 6, '2019': 6, '2013': 5, '2016': 5, '2005': 4, '2007': 4, '2004': 4, '2010': 3, '2006': 3, '2003': 2})
#
# NLGN4X
# 66
# Counter({'2012': 7, '2009': 6, '2013': 5, '2021': 5, '2016': 5, '2020': 5, '2019': 4, '2004': 4, '2008': 4, '2005': 3, '2006': 3, '2007': 3, '2015': 2, '2003': 2, '2010': 2, '2018': 2, '2014': 2, '2011': 1, '2017': 1})
#
# NLGN4Y
# 10
# Counter({'2020': 3, '2021': 2, '2019': 2, '2015': 1, '2005': 1, '2008': 1})
#
# NOTCH2NL
# 0
# Counter()
#
# NPAS2
# 2
# Counter({'2007': 1, '2016': 1})
#
# NR1D1
# 3
# Counter({'2019': 1, '2017': 1, '2016': 1})
#
# NR2F1
# 11
# Counter({'2020': 6, '2019': 3, '2017': 1, '2016': 1})
#
# NR3C2
# 4
# Counter({'2020': 1, '2021': 1, '2016': 1, '2019': 1})
#
# NR4A2
# 6
# Counter({'2018': 1, '2019': 1, '2015': 1, '2005': 1, '2013': 1, '2016': 1})
#
# NRCAM
# 13
# Counter({'2015': 2, '2012': 2, '2009': 2, '2019': 2, '2005': 1, '2018': 1, '2004': 1, '2006': 1, '2021': 1})
#
# NRP2
# 8
# Counter({'2019': 3, '2015': 1, '2010': 1, '2007': 1, '2017': 1, '2021': 1})
#
# NRXN1
# 119
# Counter({'2019': 15, '2012': 12, '2021': 10, '2009': 10, '2015': 10, '2013': 10, '2014': 10, '2011': 8, '2020': 8, '2018': 7, '2008': 5, '2017': 5, '2010': 4, '2016': 3, '2007': 1, '2004': 1})
#
# NRXN2
# 17
# Counter({'2018': 5, '2011': 2, '2015': 2, '2012': 2, '2019': 2, '2021': 1, '2014': 1, '2013': 1, '2020': 1})
#
# NRXN3
# 13
# Counter({'2018': 4, '2012': 4, '2014': 2, '2011': 1, '2021': 1, '2013': 1})
#
# NSD1
# 3
# Counter({'2019': 1, '2007': 1, '2015': 1})
#
# NTNG1
# 5
# Counter({'2015': 2, '2012': 2, '2020': 1})
#
# NTNG2
# 3
# Counter({'2019': 1, '2021': 1, '2018': 1})
#
# NTRK1
# 1
# Counter({'2009': 1})
#
# NTRK2
# 8
# Counter({'2015': 2, '2020': 2, '2021': 1, '2010': 1, '2013': 1, '2018': 1})
#
# NTRK3
# 1
# Counter({'2013': 1})
#
# NSMCE3
# 1
# Counter({'2001': 1})
#
# NUAK1
# 1
# Counter({'2018': 1})
#
# NUDCD2
# 0
# Counter()
#
# NUP133
# 0
# Counter()
#
# NXPH1
# 1
# Counter({'2011': 1})
#
# OCRL
# 4
# Counter({'2020': 2, '2012': 1, '2018': 1})
#
# ODF3L2
# 0
# Counter()
#
# OFD1
# 1
# Counter({'2020': 1})
#
# OPHN1
# 6
# Counter({'2011': 1, '2014': 1, '2009': 1, '2016': 1, '2019': 1, '2012': 1})
#
# OR1C1
# 1
# Counter({'2021': 1})
#
# OR2M4
# 1
# Counter({'2015': 1})
#
# OR2T10
# 0
# Counter()
#
# OR52M1
# 0
# Counter()
#
# OTUD7A
# 3
# Counter({'2018': 1, '2020': 1, '2016': 1})
#
# OTX1
# 2
# Counter({'2013': 1, '2011': 1})
#
# OXT
# 85
# Counter({'2018': 13, '2016': 12, '2020': 11, '2021': 10, '2017': 6, '2019': 6, '2015': 6, '2012': 5, '2014': 4, '2008': 4, '2013': 4, '2011': 2, '2009': 1, '2010': 1})
#
# MSRA
# 2
# Counter({'2009': 1, '2010': 1})
#
# NKX2-2
# 4
# Counter({'2021': 2, '2019': 1, '2018': 1})
#
# NOVA2
# 0
# Counter()
#
# NUP155
# 0
# Counter()
#
# NXF1
# 0
# Counter()
#
# OXTR
# 148
# Counter({'2017': 17, '2016': 16, '2019': 14, '2018': 13, '2020': 12, '2012': 11, '2021': 11, '2015': 10, '2014': 8, '2010': 7, '2008': 7, '2013': 6, '2011': 5, '2006': 3, '2009': 3, '2007': 2, '2022': 1, '2004': 1, '2005': 1})
#
# P2RX5
# 0
# Counter()
#
# P4HA2
# 0
# Counter()
#
# PACS1
# 2
# Counter({'2021': 1, '2017': 1})
#
# PACS2
# 1
# Counter({'2019': 1})
#
# PAFAH1B2
# 1
# Counter({'2018': 1})
#
# PAH
# 90
# Counter({'2020': 16, '2013': 9, '2012': 9, '2021': 7, '2019': 7, '2011': 6, '2014': 5, '2017': 5, '2016': 5, '2010': 4, '2008': 4, '2018': 4, '2015': 3, '2007': 3, '2022': 1, '1975': 1, '2009': 1})
#
# PAK1
# 0
# Counter()
#
# PAK2
# 0
# Counter()
#
# PAPOLG
# 0
# Counter()
#
# NSD2
# 0
# Counter()
#
# PARD3B
# 0
# Counter()
#
# PAX5
# 2
# Counter({'2020': 1, '2014': 1})
#
# PAX6
# 35
# Counter({'2016': 6, '2020': 4, '2017': 3, '2021': 3, '2008': 3, '2011': 2, '2013': 2, '2015': 2, '2019': 2, '2014': 2, '2018': 2, '2006': 1, '1993': 1, '2009': 1, '2010': 1})
#
# PBX1
# 0
# Counter()
#
# PCCA
# 0
# Counter()
#
# PCCB
# 3
# Counter({'2018': 1, '2016': 1, '2020': 1})
#
# PCDH10
# 6
# Counter({'2017': 2, '2021': 1, '2019': 1, '2012': 1, '2008': 1})
#
# PCDH11X
# 1
# Counter({'2006': 1})
#
# PCDH15
# 1
# Counter({'2016': 1})
#
# PCDH19
# 15
# Counter({'2019': 5, '2020': 3, '2018': 2, '2016': 2, '2015': 1, '2012': 1, '2013': 1})
#
# PATJ
# 0
# Counter()
#
# PCDH9
# 4
# Counter({'2010': 1, '2008': 1, '2015': 1, '2013': 1})
#
# PCDHA1
# 0
# Counter()
#
# PCDHA10
# 0
# Counter()
#
# PCDHA11
# 0
# Counter()
#
# PCDHA12
# 1
# Counter({'2020': 1})
#
# PCDHA13
# 0
# Counter()
#
# PCDHA2
# 0
# Counter()
#
# PCDHA3
# 0
# Counter()
#
# PCDHA4
# 0
# Counter()
#
# PCDHA5
# 0
# Counter()
#
# PCDHA6
# 0
# Counter()
#
# PCDHA7
# 1
# Counter({'2021': 1})
#
# PCDHA8
# 1
# Counter({'2021': 1})
#
# PCDHA9
# 0
# Counter()
#
# PCDHAC1
# 0
# Counter()
#
# PCM1
# 3
# Counter({'2009': 1, '2017': 1, '2008': 1})
#
# PDCD1
# 1
# Counter({'2016': 1})
#
# PDE1C
# 0
# Counter()
#
# PDK2
# 0
# Counter()
#
# PER1
# 0
# Counter()
#
# PER2
# 4
# Counter({'2015': 1, '2020': 1, '2021': 1, '2016': 1})
#
# PEX7
# 2
# Counter({'2013': 1, '2012': 1})
#
# PHF2
# 0
# Counter()
#
# PHF21A
# 2
# Counter({'2019': 2})
#
# PHF3
# 0
# Counter()
#
# PHF8
# 4
# Counter({'2021': 1, '2012': 1, '2008': 1, '2014': 1})
#
# PHIP
# 1
# Counter({'2016': 1})
#
# PHRF1
# 0
# Counter()
#
# PIK3R2
# 1
# Counter({'2019': 1})
#
# PITX1
# 2
# Counter({'2007': 1, '2012': 1})
#
# PLAUR
# 4
# Counter({'2016': 1, '2008': 1, '2011': 1, '2010': 1})
#
# PLCB1
# 0
# Counter()
#
# PEBP4
# 0
# Counter()
#
# PHF12
# 0
# Counter()
#
# PLCD4
# 0
# Counter()
#
# PLN
# 1
# Counter({'2007': 1})
#
# PLXNA3
# 1
# Counter({'2021': 1})
#
# PLXNA4
# 0
# Counter()
#
# PLXNB1
# 1
# Counter({'2021': 1})
#
# PNPLA7
# 0
# Counter()
#
# POGZ
# 22
# Counter({'2016': 7, '2021': 5, '2020': 4, '2019': 2, '2015': 1, '2018': 1, '2017': 1, '1993': 1})
#
# POLA2
# 0
# Counter()
#
# PCDHAC2
# 1
# Counter({'2020': 1})
#
# PHB
# 2
# Counter({'2018': 1, '2020': 1})
#
# PHF7
# 0
# Counter()
#
# PIK3CA
# 6
# Counter({'2016': 2, '2019': 2, '2017': 1, '2011': 1})
#
# PIK3CG
# 1
# Counter({'2003': 1})
#
# PJA1
# 1
# Counter({'2020': 1})
#
# POMGNT1
# 0
# Counter()
#
# POMT1
# 0
# Counter()
#
# PON1
# 14
# Counter({'2010': 3, '2017': 3, '2014': 2, '2021': 2, '2005': 1, '2020': 1, '2004': 1, '2006': 1})
#
# POT1
# 0
# Counter()
#
# POU3F3
# 0
# Counter()
#
# PPFIA1
# 1
# Counter({'2007': 1})
#
# PPM1D
# 1
# Counter({'2017': 1})
#
# PPP1R1B
# 0
# Counter()
#
# PPP2CA
# 1
# Counter({'2017': 1})
#
# PPP2R1B
# 0
# Counter()
#
# PPP2R5D
# 6
# Counter({'2020': 2, '2017': 1, '2016': 1, '2021': 1, '1993': 1})
#
# PREX1
# 1
# Counter({'2015': 1})
#
# PRICKLE1
# 0
# Counter()
#
# PRICKLE2
# 4
# Counter({'2020': 1, '2019': 1, '2014': 1, '2013': 1})
#
# PRKAR1B
# 1
# Counter({'2021': 1})
#
# PRKCA
# 2
# Counter({'2016': 1, '2017': 1})
#
# PRKCB
# 10
# Counter({'2007': 2, '2018': 1, '2014': 1, '2005': 1, '2008': 1, '2021': 1, '2012': 1, '2019': 1, '2009': 1})
#
# PRKD1
# 1
# Counter({'2021': 1})
#
# PRKD2
# 2
# Counter({'2016': 1, '2019': 1})
#
# PRKDC
# 0
# Counter()
#
# PRKN
# 2
# Counter({'2020': 1, '2018': 1})
#
# PRODH
# 2
# Counter({'2016': 1, '2014': 1})
#
# PRPF39
# 0
# Counter()
#
# PRR12
# 1
# Counter({'2008': 1})
#
# PRUNE2
# 0
# Counter()
#
# PSD3
# 0
# Counter()
#
# PSMD12
# 1
# Counter({'2018': 1})
#
# PTBP2
# 2
# Counter({'2011': 1, '2016': 1})
#
# PTCHD1
# 20
# Counter({'2011': 4, '2019': 3, '2020': 3, '2010': 2, '2015': 2, '2008': 1, '2017': 1, '2016': 1, '2021': 1, '2012': 1, '2018': 1})
#
# PTEN
# 0
# Counter()
#
# PTCHD1-AS
# 0
# Counter()
#
# PTGS2
# 8
# Counter({'2018': 2, '2021': 1, '2012': 1, '2016': 1, '2008': 1, '2001': 1, '2014': 1})
#
# PTK7
# 0
# Counter()
#
# PTPN11
# 3
# Counter({'2021': 1, '2013': 1, '2015': 1})
#
# PTPRB
# 0
# Counter()
#
# PTPRC
# 0
# Counter()
#
# PTPRT
# 1
# Counter({'2015': 1})
#
# PXDN
# 3
# Counter({'2020': 2, '2012': 1})
#
# PYHIN1
# 0
# Counter()
#
# QRICH1
# 2
# Counter({'2021': 1, '2018': 1})
#
# RAB11FIP5
# 4
# Counter({'2015': 1, '2014': 1, '2021': 1, '2008': 1})
#
# RAB2A
# 1
# Counter({'2016': 1})
#
# RAB39B
# 7
# Counter({'2020': 2, '2021': 2, '2010': 1, '2015': 1, '2017': 1})
#
# POLR3A
# 1
# Counter({'2020': 1})
#
# PPP1R9B
# 0
# Counter()
#
# PPP3CA
# 1
# Counter({'2021': 1})
#
# PPP5C
# 0
# Counter()
#
# RAB43
# 0
# Counter()
#
# RAC1
# 25
# Counter({'2021': 5, '2016': 4, '2020': 3, '2018': 3, '2015': 3, '2017': 3, '2013': 2, '2019': 2})
#
# RAD21
# 4
# Counter({'2019': 2, '2015': 1, '2017': 1})
#
# RAD21L1
# 0
# Counter()
#
# RAI1
# 19
# Counter({'2018': 3, '2010': 2, '2015': 2, '2014': 2, '2017': 2, '2019': 2, '2008': 1, '2016': 1, '2007': 1, '1993': 1, '2020': 1, '2009': 1})
#
# RALA
# 1
# Counter({'2019': 1})
#
# RALGAPB
# 2
# Counter({'2020': 1, '2018': 1})
#
# RANBP17
# 0
# Counter()
#
# RAPGEF4
# 0
# Counter()
#
# RASSF5
# 0
# Counter()
#
# RBFOX1
# 1
# Counter({'2020': 1})
#
# RBM27
# 0
# Counter()
#
# REEP3
# 1
# Counter({'2007': 1})
#
# RELN
# 95
# Counter({'2016': 8, '2020': 8, '2004': 6, '2002': 6, '2005': 6, '2008': 5, '2012': 5, '2013': 5, '2011': 5, '2007': 5, '2014': 5, '2019': 4, '2017': 4, '2021': 4, '2010': 4, '2001': 4, '2015': 3, '2003': 3, '2018': 3, '2006': 1, '2009': 1})
#
# RERE
# 0
# Counter()
#
# RFX3
# 2
# Counter({'2021': 1, '2015': 1})
#
# RGS7
# 0
# Counter()
#
# RHEB
# 6
# Counter({'2013': 3, '2020': 1, '2021': 1, '2015': 1})
#
# RIMS1
# 5
# Counter({'2019': 2, '2015': 1, '2014': 1, '2020': 1})
#
# RIMS3
# 1
# Counter({'2010': 1})
#
# RLIM
# 0
# Counter()
#
# RNF135
# 1
# Counter({'2015': 1})
#
# RNF25
# 0
# Counter()
#
# RNF38
# 0
# Counter()
#
# ROBO2
# 2
# Counter({'2014': 1, '2008': 1})
#
# RORA
# 16
# Counter({'2013': 4, '2015': 2, '2017': 2, '2018': 2, '2014': 1, '2011': 1, '2019': 1, '2020': 1, '2012': 1, '2016': 1})
#
# RORB
# 3
# Counter({'2018': 1, '2015': 1, '2014': 1})
#
# RPL10
# 5
# Counter({'2014': 2, '2011': 1, '2006': 1, '2009': 1})
#
# RP11-1407O15.2
# 0
# Counter()
#
# RPS6KA2
# 0
# Counter()
#
# RPS6KA3
# 2
# Counter({'2013': 1, '2019': 1})
#
# SAE1
# 2
# Counter({'2016': 1, '2012': 1})
#
# SAMD11
# 2
# Counter({'2018': 1, '2015': 1})
#
# SASH1
# 0
# Counter()
#
# SATB2
# 7
# Counter({'2014': 2, '2013': 2, '2018': 1, '2012': 1, '2019': 1})
#
# SBF1
# 1
# Counter({'2016': 1})
#
# SCFD2
# 0
# Counter()
#
# SCN1A
# 40
# Counter({'2021': 7, '2012': 5, '2020': 5, '2018': 4, '2019': 4, '2013': 3, '2016': 2, '2015': 2, '2004': 2, '2011': 1, '2008': 1, '2005': 1, '2003': 1, '1993': 1, '2009': 1})
#
# RFX4
# 2
# Counter({'2021': 1, '2008': 1})
#
# RFX7
# 1
# Counter({'2021': 1})
#
# RHOXF1
# 0
# Counter()
#
# RIMS2
# 1
# Counter({'2018': 1})
#
# RIT2
# 4
# Counter({'2017': 2, '2016': 1, '2018': 1})
#
# RSRC1
# 0
# Counter()
#
# SATB1
# 1
# Counter({'2021': 1})
#
# SCAF4
# 0
# Counter()
#
# SCN2A
# 64
# Counter({'2021': 14, '2019': 13, '2020': 8, '2018': 6, '2017': 5, '2016': 5, '2015': 2, '2014': 2, '2004': 2, '2008': 2, '2013': 2, '2012': 1, '2010': 1, '2003': 1})
#
# RPS10P2-AS1
# 2
# Counter({'2019': 1, '2021': 1})
#
# SCN4A
# 0
# Counter()
#
# SCN8A
# 11
# Counter({'2021': 4, '2019': 2, '2017': 2, '2015': 1, '2020': 1, '2016': 1})
#
# SCN9A
# 4
# Counter({'2020': 1, '2018': 1, '2016': 1, '2019': 1})
#
# SCP2
# 0
# Counter()
#
# SDC2
# 0
# Counter()
#
# SEMA5A
# 0
# Counter()
#
# SERPINE1
# 2
# Counter({'2010': 1, '2008': 1})
#
# SET
# 1861
# Counter({'2021': 224, '2020': 220, '2018': 160, '2019': 155, '2017': 138, '2016': 109, '2015': 106, '2014': 94, '2013': 84, '2012': 71, '2011': 69, '2009': 56, '2010': 52, '2008': 45, '2007': 33, '2005': 28, '2006': 25, '2002': 23, '2003': 20, '2004': 19, '2001': 16, '2000': 14, '1999': 11, '1997': 9, '1995': 8, '1989': 7, '1998': 6, '1992': 6, '1988': 6, '1990': 5, '1993': 5, '1975': 4, '1994': 4, '1979': 3, '1976': 3, '1977': 3, '1983': 3, '1980': 3, '1991': 3, '1984': 3, '1996': 2, '1987': 2, '1974': 2, '1972': 1, '1986': 1})
#
# SETBP1
# 4
# Counter({'2020': 2, '2015': 1, '2014': 1})
#
# SETD1B
# 6
# Counter({'2019': 2, '2021': 2, '2018': 1, '2016': 1})
#
# SETD2
# 9
# Counter({'2015': 2, '2021': 2, '2016': 2, '2018': 1, '2020': 1, '2019': 1})
#
# SETD5
# 7
# Counter({'2018': 2, '2019': 2, '2021': 1, '2020': 1, '2014': 1})
#
# SETDB1
# 2
# Counter({'2012': 1, '2016': 1})
#
# SETDB2
# 1
# Counter({'2012': 1})
#
# SEZ6L2
# 0
# Counter()
#
# SF3B1
# 0
# Counter()
#
# SGSH
# 3
# Counter({'1993': 1, '2018': 1, '2014': 1})
#
# SGSM3
# 0
# Counter()
#
# SH3RF3
# 0
# Counter()
#
# SHANK1
# 42
# Counter({'2014': 9, '2021': 6, '2017': 6, '2018': 6, '2016': 5, '2015': 4, '2013': 2, '2019': 2, '2011': 1, '2012': 1})
#
# SHANK2
# 94
# Counter({'2018': 17, '2021': 12, '2014': 10, '2019': 9, '2020': 9, '2015': 8, '2017': 7, '2016': 7, '2012': 6, '2013': 5, '2010': 3, '2011': 1})
#
# SHANK3
# 331
# Counter({'2021': 49, '2020': 44, '2019': 39, '2018': 38, '2016': 31, '2017': 29, '2015': 22, '2014': 21, '2011': 13, '2013': 12, '2012': 12, '2009': 8, '2008': 5, '2007': 4, '2010': 2, '2005': 1, '1993': 1})
#
# SHOX
# 3
# Counter({'2017': 1, '2014': 1, '2016': 1})
#
# SIK1
# 2
# Counter({'2021': 1, '2015': 1})
#
# SIN3A
# 7
# Counter({'2021': 2, '2008': 1, '2020': 1, '2009': 1, '2016': 1, '2019': 1})
#
# SLC12A5
# 0
# Counter()
#
# SLC1A1
# 0
# Counter()
#
# SLC1A2
# 1
# Counter({'2008': 1})
#
# SLC22A9
# 0
# Counter()
#
# SLC24A2
# 0
# Counter()
#
# SLC25A12
# 0
# Counter()
#
# SLC25A39
# 0
# Counter()
#
# SETD1A
# 4
# Counter({'2019': 1, '2016': 1, '2018': 1, '2021': 1})
#
# SIN3B
# 1
# Counter({'2021': 1})
#
# SKI
# 3
# Counter({'2021': 2, '2013': 1})
#
# SLC27A4
# 0
# Counter()
#
# SLC29A4
# 1
# Counter({'2014': 1})
#
# SLC38A10
# 1
# Counter({'2011': 1})
#
# SLC45A1
# 1
# Counter({'2021': 1})
#
# SLC4A10
# 1
# Counter({'2014': 1})
#
# SLC6A1
# 1
# Counter({'2020': 1})
#
# SLC6A3
# 1
# Counter({'2018': 1})
#
# SLC6A4
# 0
# Counter()
#
# SLC6A8
# 1
# Counter({'2017': 1})
#
# SLC7A3
# 0
# Counter()
#
# SLC7A5
# 5
# Counter({'2020': 2, '2016': 2, '2009': 1})
#
# SLC7A7
# 2
# Counter({'2020': 1, '2017': 1})
#
# SLC9A6
# 0
# Counter()
#
# SLC9A9
# 0
# Counter()
#
# SLCO1B3
# 1
# Counter({'2016': 1})
#
# SLITRK5
# 1
# Counter({'2014': 1})
#
# SMAD4
# 3
# Counter({'2019': 2, '2021': 1})
#
# SMARCA2
# 5
# Counter({'2014': 3, '2020': 1, '2019': 1})
#
# SMARCA4
# 9
# Counter({'2014': 3, '2021': 2, '2017': 2, '2020': 1, '2016': 1})
#
# SMARCC2
# 0
# Counter()
#
# SMC1A
# 5
# Counter({'2019': 2, '2015': 2, '2017': 1})
#
# SMC3
# 5
# Counter({'2015': 2, '2019': 1, '2009': 1, '2017': 1})
#
# SMG6
# 1
# Counter({'2018': 1})
#
# SMURF1
# 0
# Counter()
#
# SNAP25
# 12
# Counter({'2020': 3, '2019': 3, '2015': 2, '2018': 1, '2014': 1, '2017': 1, '2016': 1})
#
# SND1
# 2
# Counter({'2010': 1, '2019': 1})
#
# SNTG2
# 4
# Counter({'2018': 1, '2013': 1, '2010': 1, '2007': 1})
#
# SNX14
# 0
# Counter()
#
# SNX5
# 0
# Counter()
#
# SOD1
# 6
# Counter({'2014': 1, '2019': 1, '2021': 1, '2016': 1, '2015': 1, '2017': 1})
#
# SON
# 550
# Counter({'2020': 48, '2016': 48, '2017': 42, '2021': 42, '2018': 37, '2019': 34, '2014': 33, '2015': 32, '2012': 30, '2013': 29, '2011': 21, '2008': 19, '2007': 19, '2010': 18, '2009': 16, '2005': 13, '2006': 12, '2004': 10, '1993': 8, '2001': 6, '2003': 5, '2000': 5, '2002': 4, '1994': 3, '1988': 3, '1992': 3, '1996': 2, '1995': 2, '1985': 1, '1989': 1, '1986': 1, '1982': 1, '1991': 1, '1997': 1})
#
# SOX5
# 5
# Counter({'2018': 1, '2010': 1, '2013': 1, '2015': 1, '2016': 1})
#
# SPARCL1
# 1
# Counter({'2017': 1})
#
# SPAST
# 3
# Counter({'2017': 1, '2018': 1, '2019': 1})
#
# SPEN
# 19
# Counter({'2016': 2, '2018': 2, '2011': 2, '2005': 2, '2021': 1, '2014': 1, '2012': 1, '2004': 1, '2007': 1, '2009': 1, '2015': 1, '2008': 1, '2010': 1, '2017': 1, '2020': 1})
#
# SPP2
# 0
# Counter()
#
# SRCAP
# 0
# Counter()
#
# SRGAP3
# 4
# Counter({'2018': 1, '2009': 1, '2021': 1, '2010': 1})
#
# SRSF11
# 2
# Counter({'2013': 1, '2018': 1})
#
# SSRP1
# 1
# Counter({'2017': 1})
#
# ST7
# 2
# Counter({'2000': 1, '2004': 1})
#
# SORCS3
# 2
# Counter({'2020': 1, '2011': 1})
#
# SOX6
# 0
# Counter()
#
# ST8SIA2
# 7
# Counter({'2016': 2, '2021': 1, '2018': 1, '2015': 1, '2014': 1, '2010': 1})
#
# STAG1
# 2
# Counter({'2020': 2})
#
# STX1A
# 0
# Counter()
#
# STXBP1
# 10
# Counter({'2019': 3, '2021': 2, '2016': 2, '1993': 1, '2014': 1, '2017': 1})
#
# STXBP5
# 0
# Counter()
#
# STYK1
# 1
# Counter({'2015': 1})
#
# SYAP1
# 0
# Counter()
#
# SYN1
# 15
# Counter({'2020': 3, '2013': 3, '2021': 2, '2019': 2, '2014': 1, '2017': 1, '2011': 1, '2015': 1, '2018': 1})
#
# SLC22A15
# 0
# Counter()
#
# SLC25A27
# 1
# Counter({'2012': 1})
#
# SLC35B1
# 1
# Counter({'2018': 1})
#
# SPTBN1
# 0
# Counter()
#
# STK39
# 0
# Counter()
#
# SUPT16H
# 4
# Counter({'2014': 1, '2019': 1, '2016': 1, '2020': 1})
#
# SYBU
# 1
# Counter({'2021': 1})
#
# SYCE1
# 0
# Counter()
#
# SYN2
# 3
# Counter({'2017': 1, '2013': 1, '2014': 1})
#
# SYNCRIP
# 2
# Counter({'2019': 1, '2021': 1})
#
# SYNE1
# 3
# Counter({'2014': 1, '2013': 1, '2020': 1})
#
# SYNGAP1
# 48
# Counter({'2019': 11, '2021': 7, '2018': 5, '2020': 5, '2013': 3, '2017': 3, '2016': 3, '2015': 3, '2012': 2, '2011': 2, '2014': 2, '1993': 1, '2010': 1})
#
# SRPRA
# 0
# Counter()
#
# SYNJ1
# 0
# Counter()
#
# SYT1
# 2
# Counter({'2018': 1, '2021': 1})
#
# TAF1
# 3
# Counter({'2019': 2, '2012': 1})
#
# TAF1C
# 2
# Counter({'2015': 1, '2010': 1})
#
# TAF6
# 0
# Counter()
#
# TANC2
# 2
# Counter({'2019': 1, '2020': 1})
#
# TAOK1
# 0
# Counter()
#
# TAOK2
# 7
# Counter({'2021': 3, '2020': 2, '2019': 1, '2012': 1})
#
# TBC1D23
# 0
# Counter()
#
# TBC1D31
# 0
# Counter()
#
# TBC1D5
# 0
# Counter()
#
# TBCK
# 0
# Counter()
#
# TBL1XR1
# 9
# Counter({'2017': 2, '2020': 2, '2014': 2, '2021': 1, '2012': 1, '2019': 1})
#
# TBR1
# 30
# Counter({'2020': 6, '2021': 4, '2018': 4, '2019': 3, '2017': 3, '2015': 3, '2013': 2, '2014': 2, '2016': 1, '2012': 1, '2010': 1})
#
# TBX1
# 8
# Counter({'2012': 2, '2013': 1, '2011': 1, '2019': 1, '2021': 1, '2018': 1, '2016': 1})
#
# TCF20
# 0
# Counter()
#
# TCF4
# 27
# Counter({'2021': 5, '2018': 5, '2020': 3, '2012': 3, '2017': 2, '2014': 2, '2015': 2, '2013': 1, '2016': 1, '2019': 1, '1993': 1, '2010': 1})
#
# TCF7L2
# 0
# Counter()
#
# TECTA
# 0
# Counter()
#
# TERF2
# 0
# Counter()
#
# TET2
# 1
# Counter({'2014': 1})
#
# THBS1
# 3
# Counter({'2018': 1, '2014': 1, '2015': 1})
#
# THRA
# 6
# Counter({'2007': 1, '2017': 1, '2018': 1, '2020': 1, '1995': 1, '2021': 1})
#
# TLK2
# 2
# Counter({'2021': 1, '2019': 1})
#
# TM4SF19
# 0
# Counter()
#
# TM4SF20
# 0
# Counter()
#
# TMEM39B
# 0
# Counter()
#
# TMLHE
# 8
# Counter({'2012': 2, '2015': 2, '2011': 1, '2019': 1, '2017': 1, '2016': 1})
#
# TERB2
# 0
# Counter()
#
# SYP
# 23
# Counter({'2021': 7, '2012': 3, '2017': 2, '2015': 2, '2016': 2, '2018': 2, '2019': 1, '2013': 1, '1997': 1, '2020': 1, '1993': 1})
#
# TBX22
# 1
# Counter({'2020': 1})
#
# TEK
# 700
# Counter({'2021': 67, '2017': 48, '2015': 43, '2018': 43, '2019': 42, '2020': 40, '2013': 39, '2016': 38, '2011': 28, '2014': 24, '2012': 19, '1993': 18, '1988': 18, '1994': 18, '2009': 15, '1990': 15, '1996': 15, '1991': 14, '1995': 14, '1987': 14, '2010': 13, '1989': 12, '2008': 11, '1992': 11, '2007': 9, '2001': 8, '1998': 7, '1986': 7, '1985': 7, '2004': 6, '2005': 6, '2006': 6, '1997': 6, '1999': 5, '2003': 4, '2002': 4, '2000': 2, '1970': 1, '1975': 1, '1976': 1, '1984': 1})
#
# TET3
# 2
# Counter({'2014': 1, '2020': 1})
#
# TFB2M
# 1
# Counter({'2018': 1})
#
# TM9SF4
# 0
# Counter()
#
# TMEM134
# 0
# Counter()
#
# TNRC6B
# 3
# Counter({'2014': 1, '2021': 1, '2020': 1})
#
# TOP3B
# 0
# Counter()
#
# TRAF7
# 0
# Counter()
#
# TRAPPC6B
# 1
# Counter({'2018': 1})
#
# TRAPPC9
# 7
# Counter({'2020': 2, '2014': 2, '2021': 2, '2019': 1})
#
# TNS2
# 0
# Counter()
#
# TRIO
# 90
# Counter({'2021': 20, '2020': 13, '2019': 10, '2018': 10, '2017': 7, '2016': 5, '2015': 5, '2011': 5, '2013': 3, '2007': 3, '2005': 2, '2010': 2, '2008': 2, '1993': 1, '2014': 1, '2009': 1})
#
# TRIP12
# 5
# Counter({'2020': 2, '2017': 2, '2014': 1})
#
# TRPC6
# 4
# Counter({'2013': 1, '2011': 1, '2015': 1, '2009': 1})
#
# TRPM1
# 3
# Counter({'2020': 1, '2016': 1, '2013': 1})
#
# TRRAP
# 3
# Counter({'2017': 1, '2019': 1, '2018': 1})
#
# TSC1
# 82
# Counter({'2020': 13, '2015': 9, '2017': 9, '2021': 8, '2011': 7, '2018': 7, '2013': 7, '2016': 6, '2012': 4, '2019': 4, '2010': 2, '2009': 2, '2006': 2, '2004': 1, '2014': 1})
#
# TSC2
# 96
# Counter({'2020': 13, '2015': 12, '2021': 12, '2018': 9, '2011': 8, '2017': 7, '2016': 5, '2013': 5, '2012': 5, '2019': 5, '2014': 4, '2010': 3, '2009': 2, '2006': 2, '2005': 1, '1997': 1, '2003': 1, '2004': 1})
#
# TSHZ3
# 5
# Counter({'2020': 2, '2021': 1, '2016': 1, '2019': 1})
#
# TSPAN17
# 0
# Counter()
#
# TSPAN4
# 1
# Counter({'2016': 1})
#
# TSPAN7
# 3
# Counter({'2011': 1, '2021': 1, '2009': 1})
#
# TTI2
# 0
# Counter()
#
# TTN
# 2
# Counter({'2015': 1, '2020': 1})
#
# TUBGCP5
# 5
# Counter({'2017': 1, '2020': 1, '2015': 1, '2021': 1, '2013': 1})
#
# TSPOAP1
# 1
# Counter({'2009': 1})
#
# UBE3A
# 87
# Counter({'2018': 10, '2019': 9, '2015': 8, '2020': 8, '2011': 7, '2016': 7, '2017': 6, '2021': 4, '2003': 3, '2004': 3, '2007': 3, '2002': 2, '2001': 2, '2013': 2, '2008': 2, '2009': 2, '2010': 2, '2005': 2, '2014': 1, '1999': 1, '2006': 1, '2000': 1, '1998': 1})
#
# UBE3C
# 1
# Counter({'2020': 1})
#
# UBN2
# 1
# Counter({'2020': 1})
#
# UBR5
# 1
# Counter({'2019': 1})
#
# UIMC1
# 0
# Counter()
#
# UNC13A
# 0
# Counter()
#
# UNC79
# 1
# Counter({'2017': 1})
#
# UNC80
# 1
# Counter({'2015': 1})
#
# UPF2
# 1
# Counter({'2019': 1})
#
# UPF3B
# 5
# Counter({'2018': 2, '2019': 1, '2013': 1, '2010': 1})
#
# TRAPPC2L
# 0
# Counter()
#
# TRIM23
# 0
# Counter()
#
# TRIM32
# 6
# Counter({'2014': 2, '2020': 2, '2011': 1, '2021': 1})
#
# UNC5D
# 0
# Counter()
#
# USH2A
# 3
# Counter({'2019': 2, '2010': 1})
#
# USP15
# 1
# Counter({'2017': 1})
#
# USP45
# 0
# Counter()
#
# USP7
# 0
# Counter()
#
# USP9X
# 6
# Counter({'2017': 2, '2020': 2, '2021': 1, '2014': 1})
#
# USP9Y
# 0
# Counter()
#
# VAMP2
# 3
# Counter({'2018': 1, '2016': 1, '2019': 1})
#
# VEZF1
# 0
# Counter()
#
# VIL1
# 0
# Counter()
#
# VPS13B
# 0
# Counter()
#
# SYT17
# 0
# Counter()
#
# TBL1X
# 1
# Counter({'2011': 1})
#
# TDO2
# 4
# Counter({'2021': 2, '2004': 1, '2019': 1})
#
# TPO
# 9
# Counter({'2021': 2, '2017': 1, '2015': 1, '2020': 1, '2007': 1, '2012': 1, '2016': 1, '2013': 1})
#
# TRIM33
# 1
# Counter({'2014': 1})
#
# TTC25
# 1
# Counter({'2017': 1})
#
# UBE2H
# 0
# Counter()
#
# VASH1
# 0
# Counter()
#
# VDR
# 18
# Counter({'2018': 5, '2020': 4, '2021': 3, '2015': 2, '2016': 1, '2017': 1, '1994': 1, '1992': 1})
#
# VSIG4
# 0
# Counter()
#
# WAC
# 3
# Counter({'1993': 1, '2020': 1, '2021': 1})
#
# WASF1
# 2
# Counter({'2014': 1, '2018': 1})
#
# WDFY3
# 5
# Counter({'2018': 2, '2020': 1, '2021': 1, '2016': 1})
#
# UBR1
# 0
# Counter()
#
# VWA7
# 0
# Counter()
#
# WDFY4
# 1
# Counter({'2019': 1})
#
# WDR26
# 2
# Counter({'2021': 2})
#
# WNK3
# 1
# Counter({'2008': 1})
#
# WNT1
# 6
# Counter({'2012': 2, '2016': 1, '2013': 1, '2019': 1, '2018': 1})
#
# WWOX
# 6
# Counter({'2019': 2, '2020': 2, '2017': 1, '2016': 1})
#
# XPC
# 1
# Counter({'1998': 1})
#
# XPO1
# 1
# Counter({'2011': 1})
#
# YEATS2
# 0
# Counter()
#
# YTHDC2
# 1
# Counter({'2016': 1})
#
# YWHAE
# 9
# Counter({'2012': 3, '2014': 2, '2020': 1, '2009': 1, '2018': 1, '2016': 1})
#
# YY1
# 3528
# Counter({'2021': 413, '2020': 373, '2018': 319, '2019': 290, '2017': 272, '2016': 235, '2015': 222, '2014': 178, '2013': 154, '2011': 136, '2012': 134, '2010': 92, '2009': 91, '2007': 75, '2008': 74, '2006': 55, '2005': 51, '2004': 39, '2002': 36, '2001': 34, '2003': 32, '2000': 22, '1995': 16, '1998': 16, '1996': 15, '1997': 14, '1999': 13, '1993': 12, '1994': 11, '1990': 10, '1986': 9, '1991': 8, '1979': 7, '1992': 7, '1988': 7, '1980': 6, '1989': 6, '1987': 5, '1975': 4, '1981': 4, '1984': 4, '1982': 4, '1985': 4, '1977': 4, '1976': 3, '2022': 3, '1972': 2, '1983': 2, '1970': 1, '1967': 1, '1968': 1, '1971': 1, '1974': 1})
#
# ZBTB16
# 1
# Counter({'2021': 1})
#
# ZBTB20
# 3
# Counter({'2013': 1, '2018': 1, '2021': 1})
#
# ZC3H11A
# 0
# Counter()
#
# ZC3H4
# 0
# Counter()
#
# ZFYVE26
# 0
# Counter()
#
# ZMYND11
# 1
# Counter({'2014': 1})
#
# ZNF18
# 1
# Counter({'2012': 1})
#
# ZNF292
# 3
# Counter({'2020': 1, '2016': 1, '2018': 1})
#
# ZNF385B
# 1
# Counter({'2014': 1})
#
# ZNF462
# 2
# Counter({'2018': 1, '2019': 1})
#
# ZNF517
# 0
# Counter()
#
# ZNF548
# 0
# Counter()
#
# ZNF559
# 0
# Counter()
#
# ZNF626
# 0
# Counter()
#
# ZNF713
# 1
# Counter({'2014': 1})
#
# ZNF774
# 0
# Counter()
#
# ZNF804A
# 12
# Counter({'2019': 3, '2014': 2, '2012': 2, '2017': 1, '2010': 1, '2015': 1, '2021': 1, '2011': 1})
#
# WWP1
# 1
# Counter({'2020': 1})
#
# XRCC6
# 1
# Counter({'2020': 1})
#
# YWHAG
# 2
# Counter({'2020': 1, '2014': 1})
#
# ZMIZ1
# 0
# Counter()
#
# ZMYM2
# 0
# Counter()
#
# ZMYND8
# 1
# Counter({'2020': 1})
#
# ZNF827
# 0
# Counter()
#
# ZSWIM6
# 0
# Counter()
#
# ZWILCH
# 5674
# Counter({'2020': 584, '2019': 543, '2021': 489, '2018': 482, '2016': 435, '2017': 414, '2015': 362, '2014': 313, '2013': 254, '2012': 233, '2011': 226, '2010': 164, '2008': 144, '2009': 135, '2007': 120, '2006': 83, '2005': 81, '2004': 65, '2002': 63, '1993': 50, '2003': 48, '2001': 41, '1994': 36, '1996': 31, '1997': 28, '1992': 26, '2000': 24, '1995': 23, '1990': 22, '1988': 22, '1999': 21, '1991': 20, '1989': 17, '1998': 15, '1987': 15, '1986': 11, '1985': 9, '1982': 6, '1978': 3, '1983': 3, '1980': 2, '1979': 2, '1984': 2, '2022': 1, '1981': 1, '1977': 1, '1975': 1, '1963': 1, '1976': 1, '1973': 1})
#
# 1963

# %%
# get best 10 genes (based on literature)
top10 = np.zeros((10,2))

for i, el in tqdm(enumerate(all_gene_dates)):
    num = len(el)
    for j in range(top10.shape[0]):
        if num > top10[j, 0]:
            for k in range(top10.shape[0]-1, j, -1):
                top10[k, :] = top10[k-1, :]
                
            top10[j, 0] = num
            top10[j, 1] = i
            break
            
            
                
print(top10)
# Out:
# 1023it [00:00, 67085.26it/s]
# [[5674. 1022.]
#  [3528.  996.]
#  [1861.  798.]
#  [ 700.  921.]
#  [ 550.  856.]
#  [ 390.  314.]
#  [ 331.  812.]
#  [ 261.  510.]
#  [ 218.  541.]
#  [ 148.  626.]]

# %%
genes = []
gene_idxs = []
new_years = []

for i in range(top10.shape[0]):
    idx = int(top10[i, 1])
    print(gene_symbols[idx])
    genes.append(gene_symbols[idx])
    gene_idxs.append(idx)
    new_years.append(all_gene_dates[idx])
# Out:
# ZWILCH
# YY1
# SET
# TEK
# SON
# FMR1
# SHANK3
# MECP2
# MTOR
# OXTR

# %%
years = np.arange(1963,2022,1)
n_bins = years.size
#fcs = [(1,0,0,0.5), (0,1,0,0.5), (0,0,1,0.5), (0.5,0.5,0,0.5), (0.5,0,0.5,0.5)]

fig = plt.figure(figsize=(8,6))
plt.hist(new_years, range(1963,2023), density=0, histtype="bar", stacked=True, alpha=0.8, label=genes)
plt.legend()
plt.xticks(years+0.5, years, rotation=90, fontsize=7)
plt.title("A stacked histogram to show the 10 SFARI genes with the highest\nnumber of autism-related PubMed articles published each year", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("# papers published", fontsize=12)
fig.savefig(f'{os.getcwd()}/results/task1-ext-stacked.pdf', dpi=fig.dpi)

# %%
data.iloc[996]
# Out:
# status                                                              9
# gene-symbol                                                       YY1
# gene-name                                     YY1transcription factor
# ensembl-id                                            ENSG00000100811
# chromosome                                                         14
# genetic-category     Rare Single Gene Mutation, Syndromic, Functional
# gene-score                                                        NaN
# syndromic                                                           1
# number-of-reports                                                   5
# Name: 996, dtype: object
