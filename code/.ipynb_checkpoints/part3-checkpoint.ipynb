# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from Bio import Entrez
from tqdm import tqdm
import pickle

# %%
data = pd.read_csv (r'data/SFARI-Genes.csv')
cols = data.columns
N, D = data.shape

# %%
def save_to_txt_file(contents, filename):
    DIR = os.getcwd() + "/results/" + filename
    
    with open(DIR, "w") as f:
        f.write(contents)
        
def save_to_pickle_file(contents, filename):
    DIR = os.getcwd() + "/data/" + filename
    
    with open(DIR, "wb") as handle:
        pickle.dump(contents, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
def open_pickle_file(filename):
    DIR = os.getcwd() + "/data/" + filename
    
    with open(DIR, "rb") as handle:
        data = pickle.load(handle)
        
    return data

def save_to_npy_file(contents, filename):
    np.save(os.getcwd() + "/data/" + filename, contents)
    
def open_npy_file(filename):
    np.load(os.getcwd() + "/data/" + filename, allow_pickle=True)
    
def parse_eid():
    DIR = os.getcwd() + "/results/task2-1-eid.txt"
    eid = {}
    
    with open(DIR) as f:
        lines = f.readlines()
        
    for l in lines:
        t1 = l.replace("\n", "").split(": ")
        gene = t1[0]

        if len(t1) > 1:
            eid[gene] = t1[1].split(", ")
        else:
            eid[gene] = ""
               
    return eid

def get_entrezs(symbols):
    entrezs = {}
    
    for s in symbols:
        entrezs[s] = eid[s]
        
    return entrezs

# %%
eid = parse_eid()

# %% [markdown]
# # Task 1

# %%
gene_scores = data["gene-score"]
score_indexes =  gene_scores[gene_scores == 1].index
symbols = data["gene-symbol"].filter(items=score_indexes, axis=0)  

print(symbols)
# Out:
# 6         ACTB
# 14        ADNP
# 16        ADSL
# 17        AFF2
# 27       AHDC1
#          ...
# 984       UBR1
# 998     ZBTB20
# 1004    ZNF292
# 1006    ZNF462
# 1019    ZMYND8
# Name: gene-symbol, Length: 206, dtype: object

# %%
ncbi_ids = get_entrezs(symbols)

txt = ""
for s in symbols:
    txt += "\n".join(ncbi_ids[s]) + "\n"
    print(ncbi_ids[s])
    
save_to_txt_file(txt, "task3.1-gs1-ids.txt")
# Out:
# ['60']
# ['23394']
# ['158']
# ['2334']
# ['27245']
# ['7915']
# ['287']
# ['288']
# ['29123']
# ['23229']
# ['57492']
# ['170302']
# ['55870']
# ['80816']
# ['546']
# ['26053']
# ['1175']
# ['29994']
# ['10295']
# ['53335']
# ['673']
# ['9024']
# ['773']
# ['775']
# ['777']
# ['55799']
# ['4076']
# ['8573']
# ['54897']
# ['6792']
# ['56853']
# ['283489']
# ['1106']
# ['1107']
# ['55636']
# ['57680']
# ['23152']
# ['4849']
# ['1387']
# ['7812']
# ['10664']
# ['1499']
# ['8452']
# ['11151']
# ['1654']
# ['10522']
# ['1717']
# ['23181']
# ['1742']
# ['1760']
# ['1788']
# ['1808']
# ['1826']
# ['1778']
# ['1859']
# ['22924']
# ['79813']
# ['8666']
# ['1995']
# ['2033']
# ['2332']
# ['2290']
# ['27086']
# ['93986']
# ['2562']
# ['2561']
# ['64599']
# ['26058']
# ['2891']
# ['2670']
# ['2770']
# ['2904']
# ['3069']
# ['283450']
# ['3097']
# ['3188']
# ['3192']
# ['3265']
# ['23096']
# ['64207']
# ['284058']
# ['83473']
# ['3745']
# ['3786']
# ['51780']
# ['10765']
# ['8242']
# ['23135']
# ['9778']
# ['4297']
# ['58508']
# ['55904']
# ['51111']
# ['8216']
# ['54551']
# ['55777']
# ['79143']
# ['4204']
# ['8861']
# ['57689']
# ['9969']
# ['23389']
# ['4208']
# ['4212']
# ['283078']
# ['4130']
# ['23040']
# ['80155']
# ['112939']
# ['26960']
# ['10787']
# ['4763']
# ['25836']
# ['10943']
# ['8648']
# ['57555']
# ['54413']
# ['57502']
# ['4306']
# ['4929']
# ['9378']
# ['9379']
# ['9369']
# ['64324']
# ['9631']
# ['55690']
# ['5053']
# ['5079']
# ['5096']
# ['57526']
# ['5252']
# ['51317']
# ['23469']
# ['55023']
# ['57649']
# ['4864']
# ['55624']
# ['5528']
# ['57479']
# ['5718']
# ['139411']
# ['5728']
# ['5754']
# ['5781']
# ['84687']
# ['5536']
# ['10743']
# ['5649']
# ['473']
# ['5991']
# ['22999']
# ['6096']
# ['6323']
# ['6304']
# ['6326']
# ['6334']
# ['26040']
# ['29072']
# ['55209']
# ['22941']
# ['85358']
# ['25942']
# ['6497']
# ['6529']
# ['10479']
# ['6595']
# ['6597']
# ['6601']
# ['6651']
# ['6660']
# ['6683']
# ['10847']
# ['6812']
# ['6853']
# ['8831']
# ['6734']
# ['26115']
# ['57551']
# ['93627']
# ['79718']
# ['10716']
# ['6942']
# ['6934']
# ['6934']
# ['11011']
# ['7010']
# ['9777']
# ['84231']
# ['7204']
# ['9320']
# ['7248']
# ['7249']
# ['57616']
# ['7337']
# ['65109']
# ['373']
# ['8239']
# ['7716']
# ['157680']
# ['51322']
# ['23001']
# ['197131']
# ['26137']
# ['23036']
# ['58499']
# ['23613']

# %%
display(data.sort_values("gene-score"))
# Out:
#       status gene-symbol                                          gene-name  \
# 838        9      SLC9A6  solute carrier family 9 (sodium/hydrogen excha...
# 398        9        HRAS  v-Ha-ras Harvey rat sarcoma viral oncogene hom...
# 802        9       SETD5                            SET domain containing 5
# 395        9      HNRNPU          heterogeneous nuclear ribonucleoprotein U
# 394        9     HNRNPH2         heterogeneous nuclear ribonucleoprotein H2
# ...      ...         ...                                                ...
# 982        9       WASF1                        WAS protein family member 1
# 987        9       WDR26                                WD repeat domain 26
# 991        9         XPC     xeroderma pigmentosum, complementation group C
# 996        9         YY1                            YY1transcription factor
# 1021       9      ZSWIM6                 zinc finger SWIM-type containing 6
#
#            ensembl-id chromosome  \
# 838   ENSG00000198689          X
# 398   ENSG00000174775         11
# 802   ENSG00000168137          3
# 395   ENSG00000153187          1
# 394   ENSG00000126945          X
# ...               ...        ...
# 982   ENSG00000112290          6
# 987   ENSG00000162923          1
# 991   ENSG00000154767          3
# 996   ENSG00000100811         14
# 1021  ENSG00000130449          5
#
#                                        genetic-category  gene-score  \
# 838    Rare Single Gene Mutation, Syndromic, Functional         1.0
# 398   Rare Single Gene Mutation, Syndromic, Genetic ...         1.0
# 802                Rare Single Gene Mutation, Syndromic         1.0
# 395    Rare Single Gene Mutation, Syndromic, Functional         1.0
# 394                Rare Single Gene Mutation, Syndromic         1.0
# ...                                                 ...         ...
# 982                                           Syndromic         NaN
# 987                Rare Single Gene Mutation, Syndromic         NaN
# 991                Rare Single Gene Mutation, Syndromic         NaN
# 996    Rare Single Gene Mutation, Syndromic, Functional         NaN
# 1021                     Syndromic, Genetic Association         NaN
#
#       syndromic  number-of-reports
# 838           1                 18
# 398           0                 12
# 802           1                 28
# 395           1                 29
# 394           0                 15
# ...         ...                ...
# 982           1                  1
# 987           1                  6
# 991           1                 11
# 996           1                  5
# 1021          1                  3
#
# [1023 rows x 9 columns]

# %% [markdown]
# # Task 2

# %%
clusters = pd.read_csv(os.getcwd() + "/data/task3-2-MCL-clusters.tsv", sep="\t")

# %%
clusters = clusters.sort_values("cluster number")
display(clusters)
# Out:
#     #clustering method  cluster number    cluster color  gene count  \
# 0                  MCL               1              Red          32
# 31                 MCL               1              Red          32
# 30                 MCL               1              Red          32
# 29                 MCL               1              Red          32
# 28                 MCL               1              Red          32
# ..                 ...             ...              ...         ...
# 186                MCL              37       Hot Pink 2           1
# 187                MCL              38         Hot Pink           1
# 188                MCL              39  Pale Violet Red           1
# 189                MCL              40             Pink           1
# 190                MCL              41      Light Coral           1
#
#     protein name    protein identifier  \
# 0           ADSL  9606.ENSP00000485525
# 31          TRIO  9606.ENSP00000339299
# 30         TANC2  9606.ENSP00000387593
# 29       SYNGAP1  9606.ENSP00000403636
# 28          SYN1  9606.ENSP00000295987
# ..           ...                   ...
# 186         ANK3  9606.ENSP00000280772
# 187        KDM5C  9606.ENSP00000364550
# 188       ZMYND8  9606.ENSP00000420095
# 189       GIGYF2  9606.ENSP00000387170
# 190        NR3C2  9606.ENSP00000350815
#
#                                    protein description
# 0    Adenylosuccinate lyase; Catalyzes two non-sequ...
# 31   Triple functional domain protein; Guanine nucl...
# 30   Protein TANC2; Tetratricopeptide repeat, ankyr...
# 29   Ras/Rap GTPase-activating protein SynGAP; Majo...
# 28   Synapsin-1; Neuronal phosphoprotein that coats...
# ..                                                 ...
# 186  Ankyrin-3; In skeletal muscle, required for co...
# 187  Lysine-specific demethylase 5C; Histone demeth...
# 188  Protein kinase C-binding protein 1; May act as...
# 189  GRB10-interacting GYF protein 2; Key component...
# 190  Mineralocorticoid receptor; Receptor for both ...
#
# [191 rows x 7 columns]

# %%
cluster_sizes = clusters.value_counts("cluster number")
top2_cluster_ids = list(top2_clusters.iloc[0:2].index)
top2_cluster_sizes = list(top2_clusters.iloc[0:2])

# %%
top2_cluster_genes = []

for i, cid in enumerate(top2_cluster_ids):
    idxs = clusters.index[clusters["cluster number"] == cid].tolist()
    cluster_genes = clusters.filter(items=idxs, axis=0).sort_values("protein name")["protein name"].values
    top2_cluster_genes.append(cluster_genes)
    file_output_str = " ".join(cluster_genes)
    save_to_txt_file(file_output_str, f"part3-task2-pdb-c{i+1}.txt")

# %%
top2_cluster_genes[1].size
# Out:
# 25

# %%
def load_pdb_txt_file(filename):
    DIR = os.getcwd() + "/data/"
    data = open(DIR + filename + ".txt", "r").read()
    sep_data = data.split("\n")
    if sep_data[-1] == "":
        sep_data = sep_data[0:-1]
    output = np.array([line.split("\t") for line in sep_data], dtype=object)
    
    idxs = output[:,0].astype(int)
    cats = output[:,1]
    num_genes = output[:,2].astype(int)
    ghg = np.array([val[:-1] for val in output[:,3]]).astype(float)
    ghp = np.array([val[:-1] for val in output[:,4]]).astype(float)
    
    df_data = np.vstack((idxs, cats, num_genes, ghg, ghp)).T
    print(df_data.shape)
    return pd.DataFrame(df_data, columns=["1", "2", "3", "4", "5"])

# %%
c1 = load_pdb_txt_file("task3-2-pdb-c1")
c2 = load_pdb_txt_file("task3-2-pdb-c2")
# Out:
# (13, 5)
# (9, 5)

# %%
c1, c2 = c1.sort_values("3"), c2.sort_values("3")
num_rows = [c1.shape[0], c2.shape[0]]
num_genes = [c1["3"].values, c2["3"].values]
names = [c1["2"].values, c2["2"].values]

# %%
fig, axs = plt.subplots(2)

for i in range(2):
    ticks = np.arange(num_rows[i])
    axs[i].barh(ticks, width=num_genes[i], height=0.5)
    axs[i].set_yticks(ticks)
    axs[i].set_yticklabels(names[i], fontsize=12)
    axs[i].figure.set_figheight(num_rows[i])
    axs[i].set_title(f"MCL cluster {i+1}",fontsize=11)
    axs[i].grid(True)

fig.suptitle("Bar charts to show the frequency of SFARI genes associated\nwith each type of pathway", fontsize=16)
fig.text(0.5, 0.05, '# genes', ha='center', fontsize=14)
fig.text(-1.3, 0.5, 'Pathway category (Accession)', va='center', rotation='vertical', fontsize=14)
# Out:
# Text(-1.3, 0.5, 'Pathway category (Accession)')

# %%
def get_ticks(labels, master_labels, master_ticks):
    gaps = []
    ticks = master_ticks
    
    for i, l in enumerate(master_labels):
        if not l in labels:
            gaps.append(i)

    return np.delete(ticks, gaps)

def get_all_unique_cats(arrs):
    return np.unique(np.concatenate(arrs))

# %%
ax = plt.subplot()

c1, c2 = c1.sort_values("3"), c2.sort_values("3")
num_rows = [c1.shape[0], c2.shape[0]]
num_genes = [c1["3"].values, c2["3"].values]
names = [c1["2"].values, c2["2"].values]

all_process_labels = get_all_unique_cats(names)

num_ticks = all_process_labels.size

width = 0.4
loc = 0.2
scale = 1000
offsets = [loc, -loc]
colours = ["b", "r"]
ticks = np.arange(num_ticks)*-1
plt_labels = ["MCL cluster 1", "MCL cluster 2"]


for f in range(2):
    f_ticks = get_ticks(names[f], all_process_labels, ticks)
    ax.barh(f_ticks + offsets[f], width=num_genes[f], height=width, color=colours[f], align="center", label=plt_labels[f])
    
ax.set_yticks(ticks)
ax.set_yticklabels(all_process_labels, fontsize=12)
ax.set_ylabel("Category (Accession)", fontsize=14)
ax.set_xlabel("# genes", fontsize=14)
ax.set_title("A bar chart to show the frequency of SFARI genes associated\nwith each pathway for the largest 2 MCL clusters", fontsize=16)
ax.legend(fontsize=14)
ax.figure.set_figheight(8)
plt.grid(True)
